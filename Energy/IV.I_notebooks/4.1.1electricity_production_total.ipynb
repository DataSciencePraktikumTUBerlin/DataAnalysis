# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %% [markdown]
# load data

# %%
source_name = 'bp_elec_gen.csv'
df = pd.read_csv('source_data/Energy/' + source_name, index_col=0)
#df.set_index("Country", inplace = True)

# %%
df  = df.iloc[:, 15:-3]

df
# Out:
#                                            2000          2001          2002  \
# Country
# NaN                                         NaN           NaN           NaN
# Canada                               603.816107    587.754603    599.791955
# Mexico                               203.628061    210.212142    215.722271
# US                                  4052.253106   3984.467890   4111.775538
# Total North America                 4859.697274   4782.434635   4927.289764
# ...                                         ...           ...           ...
# NaN                                         NaN           NaN           NaN
# Total World                        15555.284220  15788.584500  16345.179040
# of which: OECD                      9861.254724   9855.512007  10079.627470
#                  Non-OECD           5694.029492   5933.072494   6265.551572
#                  European Union #   3037.654746   3119.681629   3142.872950
#
#                                            2003          2004          2005  \
# Country
# NaN                                         NaN           NaN           NaN
# Canada                               588.269630    598.509647    624.240404
# Mexico                               224.903084    235.396556    247.970751
# US                                  4137.978842   4231.682747   4322.786632
# Total North America                 4951.151555   5065.588950   5194.997787
# ...                                         ...           ...           ...
# NaN                                         NaN           NaN           NaN
# Total World                        16923.717360  17726.323520  18453.612360
# of which: OECD                     10197.546380  10447.325510  10684.804120
#                  Non-OECD           6726.170976   7278.998009   7768.808243
#                  European Union #   3237.225485   3305.590359   3327.256762
#
#                                            2006          2007          2008  \
# Country
# NaN                                         NaN           NaN           NaN
# Canada                               612.022441    637.083956    635.100095
# Mexico                               256.224961    263.249536    269.299748
# US                                  4330.951641   4431.837021   4390.106117
# Total North America                 5199.199043   5332.170513   5294.505960
# ...                                         ...           ...           ...
# NaN                                         NaN           NaN           NaN
# Total World                        19154.858750  20045.547570  20421.150510
# of which: OECD                     10768.791830  11005.955080  11009.716440
#                  Non-OECD           8386.066918   9039.592493   9411.434076
#                  European Union #   3371.216544   3384.290365   3388.664216
#
#                                            2009          2010          2011  \
# Country
# NaN                                         NaN           NaN           NaN
# Canada                               613.917434    606.979035    638.281613
# Mexico                               267.753583    275.567402    292.143242
# US                                  4206.493361   4394.250985   4363.377155
# Total North America                 5088.164378   5276.797422   5293.802010
# ...                                         ...           ...           ...
# NaN                                         NaN           NaN           NaN
# Total World                        20264.409830  21569.892030  22256.639510
# of which: OECD                     10577.182260  10998.098590  10948.179240
#                  Non-OECD           9687.227567  10571.793450  11308.460260
#                  European Union #   3224.353177   3364.676396   3299.237582
#
#                                            2012          2013          2014  \
# Country
# NaN                                         NaN           NaN           NaN
# Canada                               636.542872    655.681025    647.552346
# Mexico                               296.395954    297.117849    303.315833
# US                                  4310.569202   4330.292888   4363.326407
# Total North America                 5243.508028   5283.091761   5314.194586
# ...                                         ...           ...           ...
# NaN                                         NaN           NaN           NaN
# Total World                        22804.728410  23433.523970  24029.781560
# of which: OECD                     10955.283320  10944.142520  10882.869210
#                  Non-OECD          11849.445080  12489.381450  13146.912350
#                  European Union #   3295.421276   3269.582849   3188.387165
#
#                                            2015          2016          2017  \
# Country
# NaN                                         NaN           NaN           NaN
# Canada                               659.349360    662.985032    664.525146
# Mexico                               310.349642    320.344722    329.085355
# US                                  4348.669440   4347.910814   4302.539017
# Total North America                 5318.368443   5331.240569   5296.149518
# ...                                         ...           ...           ...
# NaN                                         NaN           NaN           NaN
# Total World                        24266.272110  24922.864810  25643.044330
# of which: OECD                     10931.193850  11005.310930  11055.232570
#                  Non-OECD          13335.078250  13917.553880  14587.811760
#                  European Union #   3236.618786   3259.430731   3289.981791
#
#                                            2018          2019
# Country
# NaN                                         NaN           NaN
# Canada                               652.270900    660.421858
# Mexico                               349.298889    363.970083
# US                                  4457.415464   4401.299402
# Total North America                 5458.985253   5425.691344
# ...                                         ...           ...
# NaN                                         NaN           NaN
# Total World                        26652.736190  27004.660520
# of which: OECD                     11246.138070  11135.995570
#                  Non-OECD          15406.598120  15868.664950
#                  European Union #   3270.058399   3215.296177
#
# [110 rows x 20 columns]

# %% [markdown]
# build plots for the countries we research

# %%
years = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
countries = ['China', 'Germany', 'India', 'US']

# Set figsize, grid and loop over our countries
fig, ax = plt.pyplot.subplots(1,1, figsize=(14,6))
#ax.grid(color='lightgrey')
for country in countries:
    y = df.loc[country]
    ax.plot(years, y)

# Set labels and legend
ax.set_title('Generated Electricity Total', size = 20)
ax.legend(countries)
ax.xaxis.set_label_text('Years', size = 16)
ax.yaxis.set_label_text('GigaWatts', size = 16)

# Save the figure. must be saved before .show()
plt.pyplot.savefig('electricity_production_total.png')

# Show figure
plt.pyplot.show()
