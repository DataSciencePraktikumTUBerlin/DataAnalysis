# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/februar/DataAnalysis/Energy/IV.I_notebooks'

# %%
cd ../Data\ Formated
# Out:
# /Users/paul/Desktop/TU/1datascience/februar/DataAnalysis/Energy/Data Formated

# %%
df = pd.read_csv('c_icapw_NC.csv', index_col=0)

# %%
df
# Out:
#           Country  Years  Renewable Energy Wind  (Installed capacity) MW
# 0   United States   2000                                        2377.000
# 1         Germany   2000                                        6095.000
# 2           China   2000                                         341.000
# 3           India   2000                                        1267.000
# 4   United States   2001                                        1487.000
# ..            ...    ...                                             ...
# 75          India   2018                                        2439.640
# 76  United States   2019                                        9166.800
# 77        Germany   2019                                        1979.000
# 78          China   2019                                       25813.503
# 79          India   2019                                        2217.080
#
# [80 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Years', 'Renewable Energy Wind  (Installed capacity) MW'], dtype='object')

# %%
df = df[df['Years'] > 2003]

# %%
df = df[df['Years'] < 2017]

# %% [markdown]
# build plots for the countries we research

# %%
countries = ['China', 'Germany', 'India', 'United States']

# Set figsize and loop over our countries
fig, ax = plt.pyplot.subplots(1,1, figsize=(14,6))
for country in countries:
    x = df[df['Country'] == country].Years
    y = df[df['Country'] == country]['Renewable Energy Wind  (Installed capacity) MW']
    ax.plot(x, y)

# Set labels and legend
ax.set_title('Wind Energy installed Capacity', size = 20)
ax.legend(countries)
ax.xaxis.set_label_text('Years', size = 16)
ax.yaxis.set_label_text('MegaWatts', size = 16)

ax.set_xticks(np.arange(min(x), max(x)+1, 2))
# Save the figure in 'IV.I_notebooks' directory. must be saved before .show()
# plt.pyplot.savefig('../IV.I_notebooks/4_Wind_Installed_Capacity.png')

# Show figure
plt.pyplot.show()
