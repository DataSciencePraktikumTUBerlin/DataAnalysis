# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/februar/DataAnalysis/Energy/IV.I_notebooks'

# %%
cd ../Data\ Formated
# Out:
# /Users/paul/Desktop/TU/1datascience/februar/DataAnalysis/Energy/Data Formated

# %%
df = pd.read_csv('c_icaps_NC.csv', index_col=0)

# %%
df
# Out:
#           Country  Years  Renewable Energy Solar (Installed capacity) MW
# 0   United States   2000                                          18.500
# 1         Germany   2000                                         114.000
# 2           China   2000                                          33.515
# 3           India   2000                                           0.000
# 4   United States   2001                                           3.400
# ..            ...    ...                                             ...
# 75          India   2018                                        9203.568
# 76  United States   2019                                        9114.400
# 77        Germany   2019                                        3781.000
# 78          China   2019                                       30256.301
# 79          India   2019                                        7704.560
#
# [80 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Years', 'Renewable Energy Solar (Installed capacity) MW'], dtype='object')

# %%
df = df[df['Years'] > 2003]

# %%
df = df[df['Years'] < 2017]

# %% [markdown]
# build plots for the countries we research

# %%
countries = ['China', 'Germany', 'India', 'United States']

# Set figsize and loop over our countries
fig, ax = plt.pyplot.subplots(1,1, figsize=(14,6))
for country in countries:
    x = df[df['Country'] == country].Years
    y = df[df['Country'] == country]['Renewable Energy Solar (Installed capacity) MW']
    ax.plot(x, y)

# Set labels and legend
ax.set_title('Solar Energy installed Capacity', size = 20)
ax.legend(countries)
ax.xaxis.set_label_text('Years', size = 16)
ax.yaxis.set_label_text('MegaWatts', size = 16)

ax.set_xticks(np.arange(min(x), max(x)+1, 2))
# Save the figure in 'IV.I_notebooks' directory. must be saved before .show()
plt.pyplot.savefig('../IV.I_notebooks/3_Solar_Installed_Capacity.png')

# Show figure
plt.pyplot.show()
