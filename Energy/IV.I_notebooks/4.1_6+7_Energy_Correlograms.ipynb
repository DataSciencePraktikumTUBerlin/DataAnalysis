# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd ..
# Out:
# /Users/paul/Desktop/TU/1datascience/februar/DataAnalysis/Energy

# %%
# load the csv files
df = pd.read_csv('energy.csv', index_col=0)  
df
# Out:
#           Country  Year  Renewable share electricity production (%)  \
# 0           China  2004                                       16.22
# 1           China  2005                                       16.18
# 2           China  2006                                       15.59
# 3           China  2007                                       15.26
# 4           China  2008                                       17.74
# 5           China  2009                                       17.86
# 6           China  2010                                       18.83
# 7           China  2011                                       16.95
# 8           China  2012                                       20.12
# 9           China  2013                                       20.45
# 10          China  2014                                       22.79
# 11          China  2015                                       24.13
# 12          China  2016                                       25.40
# ...

# %%
cols_list = list(df)
cols_list
# Out:
# ['Country',
#  'Year',
#  'Renewable share electricity production (%)',
#  'Renewable Energy Solar (Installed capacity) (MW)',
#  'Renewables:Consumption (EJ)',
#  'Electricity generation (TWh)',
#  'Wind and solar share electricity production (%)',
#  'Renewable Energy Wind  (Installed capacity) (MW)',
#  'Electricity Consumption (TWh)',
#  'Asset investment in renewables (Billions USD)',
#  'Renewable installed PV Power (GW)',
#  'Primary Energy: Consumption (EJ)',
#  'Electricity Production (TWh)',
#  'Electricity generation from other (TWh)',
#  'Energy intensity level of primary energy (MJ/2011 USD PPP) ',
#  'Renewable electricity share of total electricity output (%) ',
#  'Renewable energy share of TFEC (%) ',
#  'Total electricity output (GWh) ',
#  'Total final energy consumption (TFEC) (TJ) ',
#  'Renewable installed Wind Power (GW)']

# %%
del df['Asset investment in renewables (Billions USD)']

# %%
# list of years
years = list(df['Year'].unique())
years
# Out:
# [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
# list of countries
countries = list(df['Country'].unique())
countries
# Out:
# ['China', 'Germany', 'India', 'United States']

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(25, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(15, 130, as_cmap=True)

# sns.set(font_scale=2)

# Draw the heatmap with the mask and correct aspect ratio
sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})



# Save the figure. must be saved before .show()
fig = sns_plot.get_figure()
fig.savefig("IV.I_notebooks/6_Energy_Correlogram.png", bbox_inches='tight')



sns_plot
# Out:
# <AxesSubplot:>

# %%
# kill lower triangle
corr2 = corr * mask
corr2
# Out:
#                                                     Year  \
# Year                                                 1.0
# Renewable share electricity production (%)           0.0
# Renewable Energy Solar (Installed capacity) (MW)     0.0
# Renewables:Consumption (EJ)                          0.0
# Electricity generation (TWh)                         0.0
# Wind and solar share electricity production (%)      0.0
# Renewable Energy Wind  (Installed capacity) (MW)     0.0
# Electricity Consumption (TWh)                        0.0
# Renewable installed PV Power (GW)                    0.0
# Primary Energy: Consumption (EJ)                     0.0
# Electricity Production (TWh)                         0.0
# Electricity generation from other (TWh)              0.0
# Energy intensity level of primary energy (MJ/20...  -0.0
# Renewable electricity share of total electricit...   0.0
# Renewable energy share of TFEC (%)                  -0.0
# ...

# %%
corr2.loc['Primary Energy: Consumption (EJ)', 'Total final energy consumption (TFEC) (TJ) ']
# Out:
# 0.9960867711992367

# %%
# return row/col pairs with correlation above 0.98

cols_list2 = list(corr2)
#cols_list2

tmp = dict()
for col in cols_list2:
    tmp[col] = corr2[corr2[col] >= 0.7].index.tolist()
    
for ind in tmp.keys():
    for name in tmp[ind]:
        if name == ind:
            tmp[ind].remove(name)

res = dict()
for key in tmp.keys():
    if tmp[key] != []:
        res[key] = tmp[key]
res
# Out:
# {'Renewable Energy Solar (Installed capacity) (MW)': ['Renewable share electricity production (%)'],
#  'Renewable Energy Wind  (Installed capacity) (MW)': ['Year',
#   'Renewable Energy Solar (Installed capacity) (MW)',
#   'Renewables:Consumption (EJ)'],
#  'Electricity Consumption (TWh)': ['Electricity generation (TWh)'],
#  'Renewable installed PV Power (GW)': ['Renewable share electricity production (%)',
#   'Renewable Energy Solar (Installed capacity) (MW)',
#   'Renewable Energy Wind  (Installed capacity) (MW)'],
#  'Primary Energy: Consumption (EJ)': ['Electricity generation (TWh)',
#   'Electricity Consumption (TWh)'],
#  'Electricity Production (TWh)': ['Electricity generation (TWh)',
#   'Electricity Consumption (TWh)',
#   'Primary Energy: Consumption (EJ)'],
#  'Electricity generation from other (TWh)': ['Renewable installed PV Power (GW)'],
#  'Renewable electricity share of total electricity output (%) ': ['Renewable share electricity production (%)'],
# ...

# %%
# delete columns to condense
df_c = df.drop(['Renewable installed PV Power (GW)', 'Primary Energy: Consumption (EJ)', 'Electricity Production (TWh)', 'Renewable electricity share of total electricity output (%) ', 'Total electricity output (GWh) ', 'Electricity Consumption (TWh)', 'Renewable installed Wind Power (GW)'], axis = 1)

# %%
# Compute the correlation matrix
corr = df_c.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(25, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(15, 130, as_cmap=True)

# sns.set(font_scale=2)

# Draw the heatmap with the mask and correct aspect ratio
sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})



# Save the figure. must be saved before .show()
fig = sns_plot.get_figure()
fig.savefig("IV.I_notebooks/7_Condensed_Energy_Correlogram.png", bbox_inches='tight')



sns_plot
# Out:
# <AxesSubplot:>
