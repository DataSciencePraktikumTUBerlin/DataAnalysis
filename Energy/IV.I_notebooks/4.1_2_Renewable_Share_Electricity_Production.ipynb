# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %% [markdown]
# load data

# %%
cd ..
# Out:
# /Users/paul/Desktop/TU/1datascience/februar/DataAnalysis/Energy

# %%
df = pd.read_csv('energy.csv', index_col=0)

# %%
df
# Out:
#           Country  Year  Renewable share electricity production (%)  \
# 0           China  2004                                       16.22
# 1           China  2005                                       16.18
# 2           China  2006                                       15.59
# 3           China  2007                                       15.26
# 4           China  2008                                       17.74
# 5           China  2009                                       17.86
# 6           China  2010                                       18.83
# 7           China  2011                                       16.95
# 8           China  2012                                       20.12
# 9           China  2013                                       20.45
# 10          China  2014                                       22.79
# 11          China  2015                                       24.13
# 12          China  2016                                       25.40
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Renewable share electricity production (%)',
#        'Renewable Energy Solar (Installed capacity) (MW)',
#        'Renewables:Consumption (EJ)', 'Electricity generation (TWh)',
#        'Wind and solar share electricity production (%)',
#        'Renewable Energy Wind  (Installed capacity) (MW)',
#        'Electricity Consumption (TWh)',
#        'Asset investment in renewables (Billions USD)',
#        'Renewable installed PV Power (GW)', 'Primary Energy: Consumption (EJ)',
#        'Electricity Production (TWh)',
#        'Electricity generation from other (TWh)',
#        'Energy intensity level of primary energy (MJ/2011 USD PPP) ',
#        'Renewable electricity share of total electricity output (%) ',
#        'Renewable energy share of TFEC (%) ',
#        'Total electricity output (GWh) ',
#        'Total final energy consumption (TFEC) (TJ) ',
#        'Renewable installed Wind Power (GW)'],
#       dtype='object')

# %% [markdown]
# build plots for the countries we research

# %%
countries = ['China', 'Germany', 'India', 'United States']

# Set figsize and loop over our countries
fig, ax = plt.pyplot.subplots(1,1, figsize=(14,6))
for country in countries:
    x = df[df['Country'] == country].Year
    y = df[df['Country'] == country]['Renewable share electricity production (%)']
    ax.plot(x, y)

# Set labels and legend
ax.set_title('Renewable Share of Electricity Production', size = 20)
ax.legend(countries)
ax.xaxis.set_label_text('Years', size = 16)
ax.yaxis.set_label_text('GigaWatts', size = 16)

# Save the figure in 'IV.I_notebooks' directory. must be saved before .show()
# plt.pyplot.savefig('IV.I_notebooks/2_Renewable_Share_Electricity_Production.png')

# Show figure
plt.pyplot.show()
