# %%
import os

import numpy as np
import pandas as pd

# %%
folder = './Data Formated'
files = os.listdir(folder)

# %%
df = pd.DataFrame()

for file in files:
    file = f'{folder}/{file}'
    
    if df.size == 0:
        df = pd.read_csv(file, index_col=0)

        continue
    
    print(file)
    df2 = pd.read_csv(file, index_col=0)
    df = df.merge(df2, on=['Country', 'Year'])

df = df.replace('..', np.nan).fillna(method='ffill')

df
# Out:
# ./Data Formated/bp_solar_instcap.csv
# ./Data Formated/bp_renew_consum.csv
# ./Data Formated/bp_elec_gen.csv
# ./Data Formated/edata_share_windsolar.csv
# ./Data Formated/bp_wind_instcap.csv
# ./Data Formated/edata_elec_consum.csv
# ./Data Formated/bloom_renew_invest.csv
# ./Data Formated/qu_solar_PV_Power00_19.csv
# ./Data Formated/bp_penergy_consum.csv
# ./Data Formated/edata_elec_prod.csv
# ./Data Formated/bp_elec_gen_other.csv
# ./Data Formated/wbank_Indic.csv
# ./Data Formated/qu_wind_Power00_19.csv
#           Country  Year  Renewable share electricity production (%)  \
# 0           China  2004                                       16.22
# 1           China  2005                                       16.18
# 2           China  2006                                       15.59
# 3           China  2007                                       15.26
# 4           China  2008                                       17.74
# ...

# %%
# check if cumilated data

for c in df.columns:
    if c in ['Country', 'Year']:
        continue
        
    print(df[c].is_monotonic_increasing)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
df.to_csv('./energy.csv')
