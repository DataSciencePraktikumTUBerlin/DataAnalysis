# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#test

sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
d
# Out:
#            A         B         C         D         E         F         G  \
# 0  -0.318854 -1.602981 -1.535218 -0.570401 -0.216728  0.254874 -0.149450
# 1  -1.230374  0.205848  0.821371 -0.493780 -1.408794 -1.216324  1.734299
# 2  -0.023842 -0.363738 -0.482943  0.739577  0.611252  0.491802  1.792924
# 3  -0.292821  0.856582  0.933473 -0.421045  1.590430 -1.063801  2.104884
# 4  -0.587376  1.751572  0.308274 -0.894283 -0.769156  0.869197  0.371381
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -1.036298 -1.177101 -2.472118 -0.370044  0.108184 -0.753487 -0.331042
# 96 -0.681074  2.203923  1.555724 -0.808559 -1.415792  0.586590  0.393986
# 97  0.616011  0.162773 -0.425326  2.040243  0.339979  0.489751  1.030780
# 98 -1.268506 -0.815121 -1.670919 -1.103345 -1.348075  0.157345  0.249971
# 99  0.719434 -1.451263  0.173934 -0.401525 -0.971152  0.531255  1.649531
#
#            H         I         J  ...         Q         R         S         T  \
# 0   2.010783 -0.096784  0.422202  ... -0.951219  0.832973 -1.000208  0.343463
# 1  -0.206790 -0.733189  0.774163  ... -0.148826 -0.606270 -1.185801  0.455504
# 2  -0.683737  1.054113 -0.615562  ... -1.120717  0.991136  1.630796 -1.900090
# 3  -1.090494  1.484521 -1.089229  ...  0.230258  0.195235  0.535839  0.684299
# 4  -0.628362 -0.922477 -0.903391  ...  1.519031  0.749896 -2.269087 -0.760599
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  2.203373 -0.319100  0.428793  ... -0.087225  0.190644 -0.506678 -0.442679
# 96  0.455118 -0.050184  1.298277  ... -0.607768  0.051741 -1.183910  0.830444
# 97  1.061831 -0.040148 -1.406366  ... -1.248445 -0.530126 -0.045328  1.314023
# 98  0.581991  0.115223 -0.898088  ...  0.227623 -0.147131  0.692395 -1.308567
# 99 -0.252332 -0.903050 -0.773817  ... -0.555178  0.768933  0.101751  0.146673
#
#            U         V         W         X         Y         Z
# 0   1.546030  0.690081 -2.045853  0.334467 -0.641459 -0.222497
# 1  -0.837645 -0.146961 -0.682350  1.487670 -1.094711 -1.654707
# 2   0.062316  0.479998  0.379609 -1.512245  0.289020  0.095524
# 3   2.821279  0.916504  0.150722  0.017747  0.006885  0.329035
# 4  -0.955502  0.923951  0.315157  1.340910  0.678992  0.594258
# ..       ...       ...       ...       ...       ...       ...
# 95 -1.186259  0.743655 -1.842236  0.702369 -0.726212 -0.792110
# 96  0.911260 -1.470621 -0.450259 -1.146024 -0.548446 -0.016534
# 97 -0.203060  0.767502  2.055105 -0.131154 -1.185281 -0.208766
# 98 -1.197288 -1.348862 -1.612158  0.968366 -0.936233 -0.733935
# 99  1.483816 -1.319752  0.101646  0.145410 -0.363424  0.937096
#
# [100 rows x 26 columns]

# %%
ascii_letters[26:]
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# load the csv files
d1 = pd.read_csv('result_df/preva_econ.csv', index_col=0)
d2 = pd.read_csv('result_df/preva_eprod.csv', index_col=0)
d3 = pd.read_csv('result_df/preva_inten.csv', index_col=0)
d4 = pd.read_csv('result_df/preva_sharo.csv', index_col=0)
d5 = pd.read_csv('result_df/preva_shart.csv', index_col=0)
d6 = pd.read_csv('result_df/prevb_sharr.csv', index_col=0)
d7 = pd.read_csv('result_df/prevb_sharw.csv', index_col=0)
d8 = pd.read_csv('result_df/prevc_egen.csv', index_col=0)
d9 = pd.read_csv('result_df/prevc_egeno.csv', index_col=0)
d10 = pd.read_csv('result_df/prevc_icapg.csv', index_col=0)   # india missing
d11 = pd.read_csv('result_df/prevc_icaps.csv', index_col=0)
d12 = pd.read_csv('result_df/prevc_icapw.csv', index_col=0)
d13 = pd.read_csv('result_df/prevc_pecon.csv', index_col=0)
d14 = pd.read_csv('result_df/prevc_r-con.csv', index_col=0)
d15 = pd.read_csv('result_df/prevf_icaps.csv', index_col=0)
d16 = pd.read_csv('result_df/prevf_icapw.csv', index_col=0)

# %%
# merge them
frames = [d2, d3, d4, d5, d6, d7, d8, d9, d11, d12, d13, d14, d15, d16]
df = d1
for frame in frames:
    df = pd.merge(df, frame)

# %%
df
# Out:
#           Country  Years  \
# 0           China   2000
# 1           China   2001
# 2           China   2002
# 3           China   2003
# 4           China   2004
# ..            ...    ...
# 63  United States   2012
# 64  United States   2013
# 65  United States   2014
# 66  United States   2015
# 67  United States   2016
#
#    Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]  \
# 0                                         30187188.73
# 1                                         30940867.04
# 2                                         32272543.97
# 3                                         35505254.39
# 4                                         41469975.08
# ..                                                ...
# 63                                        56628804.85
# 64                                        57984073.56
# 65                                        59116385.16
# 66                                        58483061.91
# 67                                                 ..
#
#    Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                             1355738
# 1                                             1480949
# 2                                             1654164
# 3                                             1910755
# 4                                             2203502
# ..                                                ...
# 63                                            4270884
# 64                                            4287114
# 65                                            4319156
# 66                                            4297048
# 67                                                 ..
#
#    Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                         10.23305051
# 1                                         9.833583306
# 2                                         9.621842057
# 3                                         9.994209983
# 4                                         10.35599738
# ..                                                ...
# 63                                        5.692995246
# 64                                        5.676035631
# 65                                        5.621145713
# 66                                         5.40839254
# 67                                                 ..
#
#    Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                         16.63949819
# 1                                         18.95851917
# 2                                          17.6186279
# 3                                         15.03704033
# 4                                         16.22326642
# ..                                                ...
# 63                                        12.00739706
# 64                                        12.63791912
# 65                                        12.95382709
# 66                                        13.22859321
# 67                                                 ..
#
#    Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                         29.73071484
# 1                                         28.45581538
# 2                                         27.09820152
# 3                                         23.94657959
# 4                                         20.24947926
# ..                                                ...
# 63                                        8.481450408
# 64                                        8.713261573
# 65                                        8.754308954
# 66                                        8.716935867
# 67                                                 ..
#
#     Renewable share electricity production  \
# 0                                    16.64
# 1                                    18.96
# 2                                    17.62
# 3                                    15.04
# 4                                    16.22
# ..                                     ...
# 63                                   12.41
# 64                                   13.03
# 65                                   13.36
# 66                                   13.63
# 67                                   15.42
#
#     Wind and solar share electricity production%  Electricity generation TWh  \
# 0                                           0.06                 1355.600000
# 1                                           0.06                 1480.802000
# 2                                           0.06                 1654.000000
# 3                                           0.06                 1910.575000
# 4                                           0.07                 2203.310000
# ..                                           ...                         ...
# 63                                          4.06                 4310.569202
# 64                                          4.84                 4330.292888
# 65                                          5.34                 4363.326407
# 66                                          5.86                 4348.669440
# 67                                          7.07                 4347.910814
#
#     Electricity generation from other TWh  \
# 0                                0.003687
# 1                                0.002308
# 2                                0.006128
# 3                                0.007895
# 4                                0.000000
# ..                                    ...
# 63                              14.502507
# 64                              14.305666
# 65                              14.071837
# 66                              14.751862
# 67                              14.353595
#
#     Renewable Energy Solar (Installed capacity) MW  \
# 0                                           33.515
# 1                                           38.020
# 2                                           56.530
# 3                                           66.600
# 4                                           76.600
# ..                                             ...
# 63                                        7328.000
# 64                                       13045.000
# 65                                       17651.000
# 66                                       23442.000
# 67                                       34716.000
#
#     Renewable Energy Wind  (Installed capacity) MW  \
# 0                                           341.00
# 1                                           383.00
# 2                                           449.00
# 3                                           547.00
# 4                                           763.00
# ..                                             ...
# 63                                        59075.00
# 64                                        59973.00
# 65                                        64232.00
# 66                                        72573.02
# 67                                        81286.00
#
#     Primary Energy: Consumption EJ  Renewables:Consumption EJ  \
# 0                        42.453161                   0.031489
# 1                        44.841977                   0.033018
# 2                        48.844607                   0.035471
# 3                        56.875222                   0.041101
# 4                        66.545716                   0.057830
# ..                             ...                        ...
# 63                       89.687765                   3.325100
# 64                       92.095480                   3.756286
# 65                       93.054168                   4.039290
# 66                       92.149004                   4.248825
# 67                       92.017799                   4.807667
#
#     Renewable installed PV Power GW  Renewable installed Wind Power GW
# 0                              0.00                              0.352
# 1                              0.00                              0.406
# 2                              0.00                              0.473
# 3                              0.00                              0.568
# 4                              0.00                              0.764
# ..                              ...                                ...
# 63                             7.33                             60.007
# 64                            12.08                             61.110
# 65                            18.32                             65.879
# 66                            25.67                             73.991
# 67                            41.00                             82.184
#
# [68 rows x 17 columns]

# %%
cols_list = list(df)
cols_list
# Out:
# ['Country',
#  'Years',
#  'Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]',
#  'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]',
#  'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]',
#  'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]',
#  'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]',
#  'Renewable share electricity production',
#  'Wind and solar share electricity production%',
#  'Electricity generation TWh',
#  'Electricity generation from other TWh',
#  'Renewable Energy Solar (Installed capacity) MW',
#  'Renewable Energy Wind  (Installed capacity) MW',
#  'Primary Energy: Consumption EJ',
#  'Renewables:Consumption EJ',
#  'Renewable installed PV Power GW',
#  'Renewable installed Wind Power GW']

# %%
# shorten columnnames
df=df.rename(columns={'Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]':'Total final energy consumption (TFEC) (TJ)'})
df=df.rename(columns={'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]':'Total electricity output (GWh)'})
df=df.rename(columns={'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]':'Energy intensity level of primary energy (MJ/2011 USD PPP)'})
df=df.rename(columns={'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]':'Renewable electricity share of total electricity output (%)'})
df=df.rename(columns={'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]':'Renewable energy share of TFEC (%)'})

# %%
# list of years
years = list(df['Years'].unique())
years
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
# list of countries
countries = list(df['Country'].unique())
countries
# Out:
# ['China', 'Germany', 'India', 'United States']

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(15, 130, as_cmap=True)

#plt.tight_layout()

# Draw the heatmap with the mask and correct aspect ratio
sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Save the figure. must be saved before .show()
fig = sns_plot.get_figure()
fig.savefig("correlogram.png", bbox_inches='tight')



sns_plot
# Out:
# <AxesSubplot:>

# %%
# kill lower triangle
corr2 = corr * mask

# %%
corr2
# Out:
#                                                 Years  \
# Years                                             1.0
# Renewable share electricity production            0.0
# Wind and solar share electricity production%      0.0
# Electricity generation TWh                        0.0
# Electricity generation from other TWh             0.0
# Renewable Energy Solar (Installed capacity) MW    0.0
# Renewable Energy Wind  (Installed capacity) MW    0.0
# Primary Energy: Consumption EJ                    0.0
# Renewables:Consumption EJ                         0.0
# Renewable installed PV Power GW                   0.0
# Renewable installed Wind Power GW                 0.0
#
#                                                 Renewable share electricity production  \
# Years                                                                         0.613238
# Renewable share electricity production                                        1.000000
# Wind and solar share electricity production%                                  0.000000
# Electricity generation TWh                                                   -0.000000
# Electricity generation from other TWh                                         0.000000
# Renewable Energy Solar (Installed capacity) MW                                0.000000
# Renewable Energy Wind  (Installed capacity) MW                                0.000000
# Primary Energy: Consumption EJ                                               -0.000000
# Renewables:Consumption EJ                                                     0.000000
# Renewable installed PV Power GW                                               0.000000
# Renewable installed Wind Power GW                                             0.000000
#
#                                                 Wind and solar share electricity production%  \
# Years                                                                               0.579407
# Renewable share electricity production                                              0.621058
# Wind and solar share electricity production%                                        1.000000
# Electricity generation TWh                                                         -0.000000
# Electricity generation from other TWh                                               0.000000
# Renewable Energy Solar (Installed capacity) MW                                      0.000000
# Renewable Energy Wind  (Installed capacity) MW                                      0.000000
# Primary Energy: Consumption EJ                                                     -0.000000
# Renewables:Consumption EJ                                                           0.000000
# Renewable installed PV Power GW                                                     0.000000
# Renewable installed Wind Power GW                                                   0.000000
#
#                                                 Electricity generation TWh  \
# Years                                                             0.269853
# Renewable share electricity production                           -0.088010
# Wind and solar share electricity production%                     -0.266678
# Electricity generation TWh                                        1.000000
# Electricity generation from other TWh                             0.000000
# Renewable Energy Solar (Installed capacity) MW                    0.000000
# Renewable Energy Wind  (Installed capacity) MW                    0.000000
# Primary Energy: Consumption EJ                                    0.000000
# Renewables:Consumption EJ                                         0.000000
# Renewable installed PV Power GW                                   0.000000
# Renewable installed Wind Power GW                                 0.000000
#
#                                                 Electricity generation from other TWh  \
# Years                                                                        0.317221
# Renewable share electricity production                                       0.233171
# Wind and solar share electricity production%                                 0.619175
# Electricity generation TWh                                                   0.222204
# Electricity generation from other TWh                                        1.000000
# Renewable Energy Solar (Installed capacity) MW                               0.000000
# Renewable Energy Wind  (Installed capacity) MW                               0.000000
# Primary Energy: Consumption EJ                                               0.000000
# Renewables:Consumption EJ                                                    0.000000
# Renewable installed PV Power GW                                              0.000000
# Renewable installed Wind Power GW                                            0.000000
#
#                                                 Renewable Energy Solar (Installed capacity) MW  \
# Years                                                                                 0.656770
# Renewable share electricity production                                                0.700190
# Wind and solar share electricity production%                                          0.705077
# Electricity generation TWh                                                            0.198973
# Electricity generation from other TWh                                                 0.648535
# Renewable Energy Solar (Installed capacity) MW                                        1.000000
# Renewable Energy Wind  (Installed capacity) MW                                        0.000000
# Primary Energy: Consumption EJ                                                        0.000000
# Renewables:Consumption EJ                                                             0.000000
# Renewable installed PV Power GW                                                       0.000000
# Renewable installed Wind Power GW                                                     0.000000
#
#                                                 Renewable Energy Wind  (Installed capacity) MW  \
# Years                                                                                 0.735150
# Renewable share electricity production                                                0.460237
# Wind and solar share electricity production%                                          0.379049
# Electricity generation TWh                                                            0.561791
# Electricity generation from other TWh                                                 0.600454
# Renewable Energy Solar (Installed capacity) MW                                        0.800893
# Renewable Energy Wind  (Installed capacity) MW                                        1.000000
# Primary Energy: Consumption EJ                                                        0.000000
# Renewables:Consumption EJ                                                             0.000000
# Renewable installed PV Power GW                                                       0.000000
# Renewable installed Wind Power GW                                                     0.000000
#
#                                                 Primary Energy: Consumption EJ  \
# Years                                                                 0.201447
# Renewable share electricity production                               -0.086262
# Wind and solar share electricity production%                         -0.331439
# Electricity generation TWh                                            0.987369
# Electricity generation from other TWh                                 0.146906
# Renewable Energy Solar (Installed capacity) MW                        0.129756
# Renewable Energy Wind  (Installed capacity) MW                        0.477531
# Primary Energy: Consumption EJ                                        1.000000
# Renewables:Consumption EJ                                             0.000000
# Renewable installed PV Power GW                                       0.000000
# Renewable installed Wind Power GW                                     0.000000
#
#                                                 Renewables:Consumption EJ  \
# Years                                                            0.622219
# Renewable share electricity production                           0.102312
# Wind and solar share electricity production%                     0.333986
# Electricity generation TWh                                       0.648853
# Electricity generation from other TWh                            0.465639
# Renewable Energy Solar (Installed capacity) MW                   0.569023
# Renewable Energy Wind  (Installed capacity) MW                   0.779903
# Primary Energy: Consumption EJ                                   0.555263
# Renewables:Consumption EJ                                        1.000000
# Renewable installed PV Power GW                                  0.000000
# Renewable installed Wind Power GW                                0.000000
#
#                                                 Renewable installed PV Power GW  \
# Years                                                                  0.629241
# Renewable share electricity production                                 0.682147
# Wind and solar share electricity production%                           0.688883
# Electricity generation TWh                                             0.229647
# Electricity generation from other TWh                                  0.660963
# Renewable Energy Solar (Installed capacity) MW                         0.993667
# Renewable Energy Wind  (Installed capacity) MW                         0.808021
# Primary Energy: Consumption EJ                                         0.161104
# Renewables:Consumption EJ                                              0.596206
# Renewable installed PV Power GW                                        1.000000
# Renewable installed Wind Power GW                                      0.000000
#
#                                                 Renewable installed Wind Power GW
# Years                                                                    0.713500
# Renewable share electricity production                                   0.468371
# Wind and solar share electricity production%                             0.331920
# Electricity generation TWh                                               0.589591
# Electricity generation from other TWh                                    0.595094
# Renewable Energy Solar (Installed capacity) MW                           0.779144
# Renewable Energy Wind  (Installed capacity) MW                           0.994856
# Primary Energy: Consumption EJ                                           0.513113
# Renewables:Consumption EJ                                                0.739526
# Renewable installed PV Power GW                                          0.787059
# Renewable installed Wind Power GW                                        1.000000

# %%
corr
# Out:
#                                                    Years  \
# Years                                           1.000000
# Renewable share electricity production          0.613238
# Wind and solar share electricity production%    0.579407
# Electricity generation TWh                      0.269853
# Electricity generation from other TWh           0.317221
# Renewable Energy Solar (Installed capacity) MW  0.656770
# Renewable Energy Wind  (Installed capacity) MW  0.735150
# Primary Energy: Consumption EJ                  0.201447
# Renewables:Consumption EJ                       0.622219
# Renewable installed PV Power GW                 0.629241
# Renewable installed Wind Power GW               0.713500
#
#                                                 Renewable share electricity production  \
# Years                                                                         0.613238
# Renewable share electricity production                                        1.000000
# Wind and solar share electricity production%                                  0.621058
# Electricity generation TWh                                                   -0.088010
# Electricity generation from other TWh                                         0.233171
# Renewable Energy Solar (Installed capacity) MW                                0.700190
# Renewable Energy Wind  (Installed capacity) MW                                0.460237
# Primary Energy: Consumption EJ                                               -0.086262
# Renewables:Consumption EJ                                                     0.102312
# Renewable installed PV Power GW                                               0.682147
# Renewable installed Wind Power GW                                             0.468371
#
#                                                 Wind and solar share electricity production%  \
# Years                                                                               0.579407
# Renewable share electricity production                                              0.621058
# Wind and solar share electricity production%                                        1.000000
# Electricity generation TWh                                                         -0.266678
# Electricity generation from other TWh                                               0.619175
# Renewable Energy Solar (Installed capacity) MW                                      0.705077
# Renewable Energy Wind  (Installed capacity) MW                                      0.379049
# Primary Energy: Consumption EJ                                                     -0.331439
# Renewables:Consumption EJ                                                           0.333986
# Renewable installed PV Power GW                                                     0.688883
# Renewable installed Wind Power GW                                                   0.331920
#
#                                                 Electricity generation TWh  \
# Years                                                             0.269853
# Renewable share electricity production                           -0.088010
# Wind and solar share electricity production%                     -0.266678
# Electricity generation TWh                                        1.000000
# Electricity generation from other TWh                             0.222204
# Renewable Energy Solar (Installed capacity) MW                    0.198973
# Renewable Energy Wind  (Installed capacity) MW                    0.561791
# Primary Energy: Consumption EJ                                    0.987369
# Renewables:Consumption EJ                                         0.648853
# Renewable installed PV Power GW                                   0.229647
# Renewable installed Wind Power GW                                 0.589591
#
#                                                 Electricity generation from other TWh  \
# Years                                                                        0.317221
# Renewable share electricity production                                       0.233171
# Wind and solar share electricity production%                                 0.619175
# Electricity generation TWh                                                   0.222204
# Electricity generation from other TWh                                        1.000000
# Renewable Energy Solar (Installed capacity) MW                               0.648535
# Renewable Energy Wind  (Installed capacity) MW                               0.600454
# Primary Energy: Consumption EJ                                               0.146906
# Renewables:Consumption EJ                                                    0.465639
# Renewable installed PV Power GW                                              0.660963
# Renewable installed Wind Power GW                                            0.595094
#
#                                                 Renewable Energy Solar (Installed capacity) MW  \
# Years                                                                                 0.656770
# Renewable share electricity production                                                0.700190
# Wind and solar share electricity production%                                          0.705077
# Electricity generation TWh                                                            0.198973
# Electricity generation from other TWh                                                 0.648535
# Renewable Energy Solar (Installed capacity) MW                                        1.000000
# Renewable Energy Wind  (Installed capacity) MW                                        0.800893
# Primary Energy: Consumption EJ                                                        0.129756
# Renewables:Consumption EJ                                                             0.569023
# Renewable installed PV Power GW                                                       0.993667
# Renewable installed Wind Power GW                                                     0.779144
#
#                                                 Renewable Energy Wind  (Installed capacity) MW  \
# Years                                                                                 0.735150
# Renewable share electricity production                                                0.460237
# Wind and solar share electricity production%                                          0.379049
# Electricity generation TWh                                                            0.561791
# Electricity generation from other TWh                                                 0.600454
# Renewable Energy Solar (Installed capacity) MW                                        0.800893
# Renewable Energy Wind  (Installed capacity) MW                                        1.000000
# Primary Energy: Consumption EJ                                                        0.477531
# Renewables:Consumption EJ                                                             0.779903
# Renewable installed PV Power GW                                                       0.808021
# Renewable installed Wind Power GW                                                     0.994856
#
#                                                 Primary Energy: Consumption EJ  \
# Years                                                                 0.201447
# Renewable share electricity production                               -0.086262
# Wind and solar share electricity production%                         -0.331439
# Electricity generation TWh                                            0.987369
# Electricity generation from other TWh                                 0.146906
# Renewable Energy Solar (Installed capacity) MW                        0.129756
# Renewable Energy Wind  (Installed capacity) MW                        0.477531
# Primary Energy: Consumption EJ                                        1.000000
# Renewables:Consumption EJ                                             0.555263
# Renewable installed PV Power GW                                       0.161104
# Renewable installed Wind Power GW                                     0.513113
#
#                                                 Renewables:Consumption EJ  \
# Years                                                            0.622219
# Renewable share electricity production                           0.102312
# Wind and solar share electricity production%                     0.333986
# Electricity generation TWh                                       0.648853
# Electricity generation from other TWh                            0.465639
# Renewable Energy Solar (Installed capacity) MW                   0.569023
# Renewable Energy Wind  (Installed capacity) MW                   0.779903
# Primary Energy: Consumption EJ                                   0.555263
# Renewables:Consumption EJ                                        1.000000
# Renewable installed PV Power GW                                  0.596206
# Renewable installed Wind Power GW                                0.739526
#
#                                                 Renewable installed PV Power GW  \
# Years                                                                  0.629241
# Renewable share electricity production                                 0.682147
# Wind and solar share electricity production%                           0.688883
# Electricity generation TWh                                             0.229647
# Electricity generation from other TWh                                  0.660963
# Renewable Energy Solar (Installed capacity) MW                         0.993667
# Renewable Energy Wind  (Installed capacity) MW                         0.808021
# Primary Energy: Consumption EJ                                         0.161104
# Renewables:Consumption EJ                                              0.596206
# Renewable installed PV Power GW                                        1.000000
# Renewable installed Wind Power GW                                      0.787059
#
#                                                 Renewable installed Wind Power GW
# Years                                                                    0.713500
# Renewable share electricity production                                   0.468371
# Wind and solar share electricity production%                             0.331920
# Electricity generation TWh                                               0.589591
# Electricity generation from other TWh                                    0.595094
# Renewable Energy Solar (Installed capacity) MW                           0.779144
# Renewable Energy Wind  (Installed capacity) MW                           0.994856
# Primary Energy: Consumption EJ                                           0.513113
# Renewables:Consumption EJ                                                0.739526
# Renewable installed PV Power GW                                          0.787059
# Renewable installed Wind Power GW                                        1.000000

# %%
# return row/col pairs with correlation above 0.98

cols_list2 = list(corr2)
#cols_list2

tmp = dict()
for col in cols_list2:
    tmp[col] = corr2[corr2[col] >= 0.7].index.tolist()
    
for ind in tmp.keys():
    for name in tmp[ind]:
        if name == ind:
            tmp[ind].remove(name)

res = dict()
for key in tmp.keys():
    if tmp[key] != []:
        res[key] = tmp[key]
res
# Out:
# {'Renewable Energy Solar (Installed capacity) MW': ['Renewable share electricity production',
#   'Wind and solar share electricity production%'],
#  'Renewable Energy Wind  (Installed capacity) MW': ['Years',
#   'Renewable Energy Solar (Installed capacity) MW'],
#  'Primary Energy: Consumption EJ': ['Electricity generation TWh'],
#  'Renewables:Consumption EJ': ['Renewable Energy Wind  (Installed capacity) MW'],
#  'Renewable installed PV Power GW': ['Renewable Energy Solar (Installed capacity) MW',
#   'Renewable Energy Wind  (Installed capacity) MW'],
#  'Renewable installed Wind Power GW': ['Years',
#   'Renewable Energy Solar (Installed capacity) MW',
#   'Renewable Energy Wind  (Installed capacity) MW',
#   'Renewables:Consumption EJ',
#   'Renewable installed PV Power GW']}

# %%
#seventyToNinety = [x for x in sev if x not in nin]

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/groupwork/DataAnalysis/Big_DF'

# %%
res.keys()
# Out:
# dict_keys(['Renewable Energy Solar (Installed capacity) MW', 'Renewable Energy Wind  (Installed capacity) MW', 'Primary Energy: Consumption EJ', 'Renewables:Consumption EJ', 'Renewable installed PV Power GW', 'Renewable installed Wind Power GW'])

# %%
# write csv
import csv
col_name = res.keys() 
with open("above99.csv", 'w') as csvFile:
        wr = csv.DictWriter(csvFile, fieldnames=col_name)
        wr.writeheader()
        for ele in res:
            wr.writerow(ele)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-1be33e5d456b> in <module>
#       6         wr.writeheader()
#       7         for ele in res:
# ----> 8             wr.writerow(ele)
#
# ~/opt/anaconda3/lib/python3.8/csv.py in writerow(self, rowdict)
#     152
#     153     def writerow(self, rowdict):
# --> 154         return self.writer.writerow(self._dict_to_list(rowdict))
#     155
#     156     def writerows(self, rowdicts):
#
# ~/opt/anaconda3/lib/python3.8/csv.py in _dict_to_list(self, rowdict)
#     145     def _dict_to_list(self, rowdict):
#     146         if self.extrasaction == "raise":
# --> 147             wrong_fields = rowdict.keys() - self.fieldnames
#     148             if wrong_fields:
#     149                 raise ValueError("dict contains fields not in fieldnames: "
#
# AttributeError: 'str' object has no attribute 'keys'
