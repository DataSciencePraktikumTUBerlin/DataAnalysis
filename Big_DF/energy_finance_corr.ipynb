# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#test

sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
d
# Out:
#            A         B         C         D         E         F         G  \
# 0  -0.318854 -1.602981 -1.535218 -0.570401 -0.216728  0.254874 -0.149450
# 1  -1.230374  0.205848  0.821371 -0.493780 -1.408794 -1.216324  1.734299
# 2  -0.023842 -0.363738 -0.482943  0.739577  0.611252  0.491802  1.792924
# 3  -0.292821  0.856582  0.933473 -0.421045  1.590430 -1.063801  2.104884
# 4  -0.587376  1.751572  0.308274 -0.894283 -0.769156  0.869197  0.371381
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -1.036298 -1.177101 -2.472118 -0.370044  0.108184 -0.753487 -0.331042
# 96 -0.681074  2.203923  1.555724 -0.808559 -1.415792  0.586590  0.393986
# 97  0.616011  0.162773 -0.425326  2.040243  0.339979  0.489751  1.030780
# 98 -1.268506 -0.815121 -1.670919 -1.103345 -1.348075  0.157345  0.249971
# 99  0.719434 -1.451263  0.173934 -0.401525 -0.971152  0.531255  1.649531
#
#            H         I         J  ...         Q         R         S         T  \
# ...

# %%
ascii_letters[26:]
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# load the csv files
d0 = pd.read_csv('result_df/investment_trends.csv', index_col=0)  # Total final energy consumption (TFEC) (TJ)
d1 = pd.read_csv('result_df/preva_econ.csv', index_col=0)  # Total final energy consumption (TFEC) (TJ)
d2 = pd.read_csv('result_df/preva_eprod.csv', index_col=0) # Total electricity output (GWh)
d3 = pd.read_csv('result_df/preva_inten.csv', index_col=0) # Energy intensity level of primary energy (MJ/2011 USD PPP)
d4 = pd.read_csv('result_df/preva_sharo.csv', index_col=0) # Renewable electricity share of total electricity output (%)
d5 = pd.read_csv('result_df/preva_shart.csv', index_col=0) # Renewable energy share of TFEC (%)
d6 = pd.read_csv('result_df/prevb_sharr.csv', index_col=0) # OUT: Renewable share electricity production
d7 = pd.read_csv('result_df/prevb_sharw.csv', index_col=0) # Wind and solar share electricity production%
d8 = pd.read_csv('result_df/prevc_egen.csv', index_col=0)  # OUT: Electricity generation TWh
d9 = pd.read_csv('result_df/prevc_egeno.csv', index_col=0) # Electricity generation from other TWh
d10 = pd.read_csv('result_df/prevc_icapg.csv', index_col=0)   # OUT: india missing: 
d11 = pd.read_csv('result_df/prevc_icaps_NC.csv', index_col=0) # Renewable Energy Solar (Installed capacity) MW
d12 = pd.read_csv('result_df/prevc_icapw_NC.csv', index_col=0) # Renewable Energy Wind  (Installed capacity) MW
d13 = pd.read_csv('result_df/prevc_pecon.csv', index_col=0) # OUT: Primary Energy: Consumption EJ
d14 = pd.read_csv('result_df/prevc_r-con.csv', index_col=0) # Renewables:Consumption EJ
d15 = pd.read_csv('result_df/prevf_icaps_NC.csv', index_col=0) # OUT: Renewable installed PV Power GW
d16 = pd.read_csv('result_df/prevf_icapw_NC.csv', index_col=0) # OUT: Renewable installed Wind Power GW

# %%
d1
# Out:
#           Country  Years  \
# 0           China   2000
# 1           China   2001
# 2           China   2002
# 3           China   2003
# 4           China   2004
# ..            ...    ...
# 62  United States   2011
# 63  United States   2012
# 64  United States   2013
# 65  United States   2014
# 66  United States   2015
#
#     Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                         30187188.73
# 1                                         30940867.04
# 2                                         32272543.97
# 3                                         35505254.39
# 4                                         41469975.08
# ..                                                ...
# 62                                        57123701.65
# 63                                        56628804.85
# 64                                        57984073.56
# 65                                        59116385.16
# ...

# %%
d0.columns
# Out:
# Index(['Government R&D', 'Corporate R&D', 'Venture capital',
#        'Private equity expansion capital', 'Public markets', 'Asset finance',
#        'Asset Finance minus Re-invested equity', 'Small distributed capacity',
#        'Private equity buy-outs', 'Public markets investor exits',
#        'Corporate M&A', 'Project acquisition & refinancing',
#        'Total: M&A/ buy-outs etc.'],
#       dtype='object')

# %%
d0['Years'] = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019] 
d0
# Out:
#       Government R&D  Corporate R&D  Venture capital  \
# 2004             1.9            1.9              0.4
# 2005             2.0            1.9              0.6
# 2006             2.2            2.2              1.2
# 2007             2.7            2.3              2.1
# 2008             2.8            3.3              3.3
# 2009             5.4            3.3              1.6
# 2010             4.9            3.8              2.6
# 2011             4.8            4.3              2.6
# 2012             4.7            4.1              2.4
# 2013             5.2            4.0              0.8
# 2014             4.5            4.3              1.0
# 2015             4.4            4.1              1.4
# 2016             5.1            4.3              0.8
# 2017             5.1            6.9              0.8
# 2018             5.5            7.8              0.2
# 2019             5.7            7.7              0.2
#
# ...

# %%
# drop 2016 - 2019
d0 = d0[:-4]
d0
# Out:
#       Government R&D  Corporate R&D  Venture capital  \
# 2004             1.9            1.9              0.4
# 2005             2.0            1.9              0.6
# 2006             2.2            2.2              1.2
# 2007             2.7            2.3              2.1
# 2008             2.8            3.3              3.3
# 2009             5.4            3.3              1.6
# 2010             4.9            3.8              2.6
# 2011             4.8            4.3              2.6
# 2012             4.7            4.1              2.4
# 2013             5.2            4.0              0.8
# 2014             4.5            4.3              1.0
# 2015             4.4            4.1              1.4
#
#       Private equity expansion capital  Public markets  Asset finance  \
# 2004                               0.3             0.3           32.1
# 2005                               1.0             3.6           50.0
# ...

# %%
# merge them
frames = [d0, d2, d3, d4, d5, d7, d9, d11, d12, d14]
df = d1
for frame in frames:
    df = pd.merge(df, frame)

# %%
df
# Out:
#           Country  Years  \
# 0           China   2004
# 1         Germany   2004
# 2           India   2004
# 3   United States   2004
# 4           China   2005
# 5         Germany   2005
# 6           India   2005
# 7   United States   2005
# 8           China   2006
# 9         Germany   2006
# 10          India   2006
# 11  United States   2006
# 12          China   2007
# 13        Germany   2007
# 14          India   2007
# 15  United States   2007
# 16          China   2008
# 17        Germany   2008
# 18          India   2008
# 19  United States   2008
# 20          China   2009
# 21        Germany   2009
# 22          India   2009
# 23  United States   2009
# 24          China   2010
# 25        Germany   2010
# 26          India   2010
# 27  United States   2010
# 28          China   2011
# 29        Germany   2011
# 30          India   2011
# 31  United States   2011
# 32          China   2012
# 33        Germany   2012
# 34          India   2012
# ...

# %%
df
# Out:
#           Country  Years  \
# 0           China   2004
# 1         Germany   2004
# 2           India   2004
# 3   United States   2004
# 4           China   2005
# 5         Germany   2005
# 6           India   2005
# 7   United States   2005
# 8           China   2006
# 9         Germany   2006
# 10          India   2006
# 11  United States   2006
# 12          China   2007
# 13        Germany   2007
# 14          India   2007
# 15  United States   2007
# 16          China   2008
# 17        Germany   2008
# 18          India   2008
# 19  United States   2008
# 20          China   2009
# 21        Germany   2009
# 22          India   2009
# 23  United States   2009
# 24          China   2010
# 25        Germany   2010
# 26          India   2010
# 27  United States   2010
# 28          China   2011
# 29        Germany   2011
# 30          India   2011
# 31  United States   2011
# 32          China   2012
# 33        Germany   2012
# 34          India   2012
# ...

# %%
cols_list = list(df)
cols_list
# Out:
# ['Country',
#  'Years',
#  'Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]',
#  'Government R&D',
#  'Corporate R&D',
#  'Venture capital',
#  'Private equity expansion capital',
#  'Public markets',
#  'Asset finance',
#  'Asset Finance minus Re-invested equity',
#  'Small distributed capacity',
#  'Private equity buy-outs',
#  'Public markets investor exits',
#  'Corporate M&A',
#  'Project acquisition & refinancing',
#  'Total: M&A/ buy-outs etc.',
#  'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]',
#  'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]',
#  'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]',
#  'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]',
#  'Wind and solar share electricity production%',
#  'Electricity generation from other TWh',
#  'Renewable Energy Solar (Installed capacity) MW',
# ...

# %%
# shorten columnnames
df=df.rename(columns={'Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]':'Total final energy consumption (TFEC) (TJ)'})
df=df.rename(columns={'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]':'Total electricity output (GWh)'})
df=df.rename(columns={'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]':'Energy intensity level of primary energy (MJ/2011 USD PPP)'})
df=df.rename(columns={'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]':'Renewable electricity share of total electricity output (%)'})
df=df.rename(columns={'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]':'Renewable energy share of TFEC (%)'})

# %%
# list of years
years = list(df['Years'].unique())
years
# Out:
# [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
# list of countries
countries = list(df['Country'].unique())
countries
# Out:
# ['China', 'Germany', 'India', 'United States']

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(25, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(15, 130, as_cmap=True)

# sns.set(font_scale=2)

# Draw the heatmap with the mask and correct aspect ratio
sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})



# Save the figure. must be saved before .show()
fig = sns_plot.get_figure()
fig.savefig("energy_finance_correlogram.png", bbox_inches='tight')



sns_plot
# Out:
# <AxesSubplot:>

# %%
# kill lower triangle
corr2 = corr * mask

# %%
corr2
# Out:
#                                                     Years  \
# Years                                                 1.0
# Total final energy consumption (TFEC) (TJ)            0.0
# Government R&D                                        0.0
# Corporate R&D                                         0.0
# Venture capital                                       0.0
# Private equity expansion capital                     -0.0
# Public markets                                        0.0
# Asset finance                                         0.0
# Asset Finance minus Re-invested equity                0.0
# Small distributed capacity                            0.0
# Private equity buy-outs                               0.0
# Public markets investor exits                        -0.0
# Corporate M&A                                         0.0
# Project acquisition & refinancing                     0.0
# Total: M&A/ buy-outs etc.                             0.0
# ...

# %%
corr2.loc['Total final energy consumption (TFEC) (TJ)', 'Primary Energy: Consumption EJ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Primary Energy: Consumption EJ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-345-c681f149160d> in <module>
# ...

# %%
corr2.loc['Total final energy consumption (TFEC) (TJ)', 'Renewables:Consumption EJ']

# %%
corr

# %%
# return row/col pairs with correlation above 0.98

cols_list2 = list(corr2)
#cols_list2

tmp = dict()
for col in cols_list2:
    tmp[col] = corr2[corr2[col] >= 0.6].index.tolist()
    
for ind in tmp.keys():
    for name in tmp[ind]:
        if name == ind:
            tmp[ind].remove(name)

res = dict()
for key in tmp.keys():
    if tmp[key] != []:
        res[key] = tmp[key]
res
# Out:
# {'Government R&D': ['Years'],
#  'Corporate R&D': ['Years', 'Government R&D'],
#  'Private equity expansion capital': ['Venture capital'],
#  'Asset finance': ['Years', 'Government R&D', 'Corporate R&D'],
#  'Asset Finance minus Re-invested equity': ['Years',
#   'Government R&D',
#   'Corporate R&D',
#   'Asset finance'],
#  'Small distributed capacity': ['Years',
#   'Government R&D',
#   'Corporate R&D',
#   'Asset Finance minus Re-invested equity'],
#  'Corporate M&A': ['Public markets'],
#  'Project acquisition & refinancing': ['Years',
#   'Government R&D',
#   'Corporate R&D',
#   'Asset finance',
#   'Asset Finance minus Re-invested equity'],
#  'Total: M&A/ buy-outs etc.': ['Years',
#   'Government R&D',
#   'Corporate R&D',
#   'Asset finance',
#   'Asset Finance minus Re-invested equity',
#   'Project acquisition & refinancing'],
#  'Total electricity output (GWh)': ['Total final energy consumption (TFEC) (TJ)'],
# ...

# %%
#seventyToNinety = [x for x in sev if x not in nin]

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/groupwork/DataAnalysis/Big_DF'

# %%
res.keys()
# Out:
# dict_keys(['Total electricity output (GWh)', 'Renewable share electricity production', 'Electricity generation TWh', 'Primary Energy: Consumption EJ', 'Renewable installed PV Power GW', 'Renewable installed Wind Power GW'])

# %%
# write csv
import csv
col_name = res.keys() 
with open("above99.csv", 'w') as csvFile:
        wr = csv.DictWriter(csvFile, fieldnames=col_name)
        wr.writeheader()
        for ele in res:
            wr.writerow(ele)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-1be33e5d456b> in <module>
#       6         wr.writeheader()
#       7         for ele in res:
# ----> 8             wr.writerow(ele)
#
# ~/opt/anaconda3/lib/python3.8/csv.py in writerow(self, rowdict)
#     152
#     153     def writerow(self, rowdict):
# --> 154         return self.writer.writerow(self._dict_to_list(rowdict))
#     155
#     156     def writerows(self, rowdicts):
#
# ~/opt/anaconda3/lib/python3.8/csv.py in _dict_to_list(self, rowdict)
#     145     def _dict_to_list(self, rowdict):
#     146         if self.extrasaction == "raise":
# --> 147             wrong_fields = rowdict.keys() - self.fieldnames
#     148             if wrong_fields:
#     149                 raise ValueError("dict contains fields not in fieldnames: "
#
# AttributeError: 'str' object has no attribute 'keys'
