# %% [markdown]
# # Generate Dataframe for each indicator, with homogene format
# This **pipeline** shows how to generate a a consistent dataframe, and its .csv file, from the *source* folder. It is a generic version, which means that for each file minor changes will be needed.

# %% [markdown]
# ## Preliminars

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Call desired data
df_meta = pd.read_csv('Indicators_metadata.csv')
source_name = 'bp_solar_instcap'
df = pd.read_csv('source_data/Energy/' + source_name + '.csv', index_col=0)  # index_col=0 reads without 'Unnamed: 0'

# %%
# call metadata of the indicator
df_meta_temp = df_meta.set_index('SOURCE FILE')
Units_ind= df_meta_temp['UNIT'][source_name]
Origin_ind= df_meta_temp['SITE'][source_name]
Name_ind =  df_meta_temp['INDICATOR'][source_name]
Key_ind =  df_meta_temp['KEY'][source_name]
Desc_ind =  df_meta_temp['DESCRIPTION'][source_name]

# %% [markdown]
# ### Preview of the DataFrame

# %%
# Check column names
df.columns
# Out:
# Index(['1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2019.1', '2008-18',
#        '2019.2'],
#       dtype='object')

# %%
df.head()
# Out:
#                      1996  1997  1998  1999  2000  2001  2002   2003   2004  \
# Country
# NaN                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# Canada                3.0   3.0   5.0   6.0   7.0   9.0  10.0   12.0   14.0
# Mexico               10.0  11.0  12.0  13.0  14.0  15.0  16.0   16.0   16.0
# US                   13.9  14.6  15.2  16.6  18.5  21.9  28.0   73.0  111.0
# Total North America  26.9  28.6  32.2  35.6  39.5  45.9  54.0  101.0  141.0
#
#                       2005  ...     2013     2014     2015     2016      2017  \
# Country                     ...
# NaN                    NaN  ...      NaN      NaN      NaN      NaN       NaN
# Canada                17.0  ...   1210.0   1843.0   2517.0   2661.0   2913.00
# Mexico                16.0  ...     82.0    116.0    173.0    388.6    673.74
# US                   190.0  ...  13045.0  17651.0  23442.0  34716.0  43115.00
# Total North America  223.0  ...  14337.0  19610.0  26132.0  37765.6  46701.74
#
#                         2018       2019    2019.1      2008-18    2019.2
# Country
# NaN                      NaN        NaN       NaN          NaN       NaN
# Canada                3100.0   3310.000  0.067742  0.575015294  0.005644
# Mexico                2555.0   4440.208  0.737850  0.632539622  0.007572
# US                   53183.5  62297.900  0.171376   0.53072859  0.106234
# Total North America  58838.5  70048.108  0.190515  0.535983574  0.119450
#
# [5 rows x 27 columns]

# %%
# Reset index to return DF to a tidy state IF NEEDED
df=df.reset_index()
# Rename column Country column
df=df.rename(columns={'Country Name':'Country'})

# %%
df['Country'].unique()
# Out:
# array(['China', 'Germany', 'India', 'United States', nan,
#        'Data from database: Sustainable Energy for All',
#        'Last Updated: 06/30/2018'], dtype=object)

# %%
# selecting rows based on condition 
df = df[df.Country.isin(['China', 'Germany', 'India', 'United States'])]

# %%
df
# Out:
#           Country Country Code    Time Time Code  \
# 0           China          CHN  2000.0    YR2000
# 1           China          CHN  2001.0    YR2001
# 2           China          CHN  2002.0    YR2002
# 3           China          CHN  2003.0    YR2003
# 4           China          CHN  2004.0    YR2004
# ..            ...          ...     ...       ...
# 63  United States          USA  2012.0    YR2012
# 64  United States          USA  2013.0    YR2013
# 65  United States          USA  2014.0    YR2014
# 66  United States          USA  2015.0    YR2015
# 67  United States          USA  2016.0    YR2016
#
#    Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                         10.23305051
# 1                                         9.833583306
# 2                                         9.621842057
# 3                                         9.994209983
# 4                                         10.35599738
# ..                                                ...
# 63                                        5.692995246
# 64                                        5.676035631
# 65                                        5.621145713
# 66                                         5.40839254
# 67                                                 ..
#
#    Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                         16.63949819
# 1                                         18.95851917
# 2                                          17.6186279
# 3                                         15.03704033
# 4                                         16.22326642
# ..                                                ...
# 63                                        12.00739706
# 64                                        12.63791912
# 65                                        12.95382709
# 66                                        13.22859321
# 67                                                 ..
#
#    Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                         29.73071484
# 1                                         28.45581538
# 2                                         27.09820152
# 3                                         23.94657959
# 4                                         20.24947926
# ..                                                ...
# 63                                        8.481450408
# 64                                        8.713261573
# 65                                        8.754308954
# 66                                        8.716935867
# 67                                                 ..
#
#    Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                             1355738
# 1                                             1480949
# 2                                             1654164
# 3                                             1910755
# 4                                             2203502
# ..                                                ...
# 63                                            4270884
# 64                                            4287114
# 65                                            4319156
# 66                                            4297048
# 67                                                 ..
#
#    Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                         30187188.73
# 1                                         30940867.04
# 2                                         32272543.97
# 3                                         35505254.39
# 4                                         41469975.08
# ..                                                ...
# 63                                        56628804.85
# 64                                        57984073.56
# 65                                        59116385.16
# 66                                        58483061.91
# 67                                                 ..
#
# [68 rows x 9 columns]

# %%
# Check country name available
df['Time'].unique()
# Out:
# array([2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008.,
#        2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.])

# %%
# Check column characteristics
df.describe()
# Out:
#               Time
# count    68.000000
# mean   2008.000000
# std       4.935404
# min    2000.000000
# 25%    2004.000000
# 50%    2008.000000
# 75%    2012.000000
# max    2016.000000

# %%
# Replace country names for consistency with other DataFrames
df['Country']=df['Country'].replace('USA', 'United States')
df['Country']=df['Country'].replace('Deutschland', 'Germany')
df['Country']=df['Country'].replace('Indien', 'India')

# %%
df
# Out:
#           Country Country Code    Time Time Code  \
# 0           China          CHN  2000.0    YR2000
# 1           China          CHN  2001.0    YR2001
# 2           China          CHN  2002.0    YR2002
# 3           China          CHN  2003.0    YR2003
# 4           China          CHN  2004.0    YR2004
# ..            ...          ...     ...       ...
# 63  United States          USA  2012.0    YR2012
# 64  United States          USA  2013.0    YR2013
# 65  United States          USA  2014.0    YR2014
# 66  United States          USA  2015.0    YR2015
# 67  United States          USA  2016.0    YR2016
#
#    Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                         10.23305051
# 1                                         9.833583306
# 2                                         9.621842057
# 3                                         9.994209983
# 4                                         10.35599738
# ..                                                ...
# 63                                        5.692995246
# 64                                        5.676035631
# 65                                        5.621145713
# 66                                         5.40839254
# 67                                                 ..
#
#    Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                         16.63949819
# 1                                         18.95851917
# 2                                          17.6186279
# 3                                         15.03704033
# 4                                         16.22326642
# ..                                                ...
# 63                                        12.00739706
# 64                                        12.63791912
# 65                                        12.95382709
# 66                                        13.22859321
# 67                                                 ..
#
#    Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                         29.73071484
# 1                                         28.45581538
# 2                                         27.09820152
# 3                                         23.94657959
# 4                                         20.24947926
# ..                                                ...
# 63                                        8.481450408
# 64                                        8.713261573
# 65                                        8.754308954
# 66                                        8.716935867
# 67                                                 ..
#
#    Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                             1355738
# 1                                             1480949
# 2                                             1654164
# 3                                             1910755
# 4                                             2203502
# ..                                                ...
# 63                                            4270884
# 64                                            4287114
# 65                                            4319156
# 66                                            4297048
# 67                                                 ..
#
#    Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                         30187188.73
# 1                                         30940867.04
# 2                                         32272543.97
# 3                                         35505254.39
# 4                                         41469975.08
# ..                                                ...
# 63                                        56628804.85
# 64                                        57984073.56
# 65                                        59116385.16
# 66                                        58483061.91
# 67                                                 ..
#
# [68 rows x 9 columns]

# %% [markdown]
# ### Set Index temporarily to ease manipulation and guarantee final homogeneity

# %%
index = ['Country']
df=df.set_index(index)

# %%
df.dropna()
# Out:
#               Country Code    Time Time Code  \
# Country
# China                  CHN  2000.0    YR2000
# China                  CHN  2001.0    YR2001
# China                  CHN  2002.0    YR2002
# China                  CHN  2003.0    YR2003
# China                  CHN  2004.0    YR2004
# ...                    ...     ...       ...
# United States          USA  2012.0    YR2012
# United States          USA  2013.0    YR2013
# United States          USA  2014.0    YR2014
# United States          USA  2015.0    YR2015
# United States          USA  2016.0    YR2016
#
#               Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# Country
# China                                                10.23305051
# China                                                9.833583306
# China                                                9.621842057
# China                                                9.994209983
# China                                                10.35599738
# ...                                                          ...
# United States                                        5.692995246
# United States                                        5.676035631
# United States                                        5.621145713
# United States                                         5.40839254
# United States                                                 ..
#
#               Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# Country
# China                                                16.63949819
# China                                                18.95851917
# China                                                 17.6186279
# China                                                15.03704033
# China                                                16.22326642
# ...                                                          ...
# United States                                        12.00739706
# United States                                        12.63791912
# United States                                        12.95382709
# United States                                        13.22859321
# United States                                                 ..
#
#               Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# Country
# China                                                29.73071484
# China                                                28.45581538
# China                                                27.09820152
# China                                                23.94657959
# China                                                20.24947926
# ...                                                          ...
# United States                                        8.481450408
# United States                                        8.713261573
# United States                                        8.754308954
# United States                                        8.716935867
# United States                                                 ..
#
#               Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# Country
# China                                                    1355738
# China                                                    1480949
# China                                                    1654164
# China                                                    1910755
# China                                                    2203502
# ...                                                          ...
# United States                                            4270884
# United States                                            4287114
# United States                                            4319156
# United States                                            4297048
# United States                                                 ..
#
#               Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# Country
# China                                                30187188.73
# China                                                30940867.04
# China                                                32272543.97
# China                                                35505254.39
# China                                                41469975.08
# ...                                                          ...
# United States                                        56628804.85
# United States                                        57984073.56
# United States                                        59116385.16
# United States                                        58483061.91
# United States                                                 ..
#
# [68 rows x 8 columns]

# %% [markdown]
# ### Select countries and time range

# %%
# Assign selected Countries (carefull with the names: Case sensitive, etc.)
sel_c = ['United States', 'India', 'Germany','China']
# Assign selected Years or interval
sel_y = [2000,2017]#one member more
sel_years = [*range(sel_y[0],sel_y[1])] #using unpacking(*) operator
sel_years_txt = [str(x) for x in sel_years]

# %%
# Check Time name available
df['Time'].unique()
# Out:
# array([2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008.,
#        2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016.])

# %%
# turn from float into int
df['Time'] = df['Time'].astype(int)

# %%
# rename as years
df.rename(columns = {'Time':'Years'}, inplace = True)
df['Years']
# Out:
# Country
# China            2000
# China            2001
# China            2002
# China            2003
# China            2004
#                  ...
# United States    2012
# United States    2013
# United States    2014
# United States    2015
# United States    2016
# Name: Years, Length: 68, dtype: int64

# %%
# Apply selection creteria
# df_p = df[sel_years]
# df_p = df_p[df_p.index.isin(sel_c)]

# %%
df_p = df[(df['Years']>0) & (df['Years']<2020)]
df_p = df_p[df_p.index.isin(sel_c)]

# %%
df_p
# Out:
#               Country Code  Years Time Code  \
# Country
# China                  CHN   2000    YR2000
# China                  CHN   2001    YR2001
# China                  CHN   2002    YR2002
# China                  CHN   2003    YR2003
# China                  CHN   2004    YR2004
# ...                    ...    ...       ...
# United States          USA   2012    YR2012
# United States          USA   2013    YR2013
# United States          USA   2014    YR2014
# United States          USA   2015    YR2015
# United States          USA   2016    YR2016
#
#               Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# Country
# China                                                10.23305051
# China                                                9.833583306
# China                                                9.621842057
# China                                                9.994209983
# China                                                10.35599738
# ...                                                          ...
# United States                                        5.692995246
# United States                                        5.676035631
# United States                                        5.621145713
# United States                                         5.40839254
# United States                                                 ..
#
#               Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# Country
# China                                                16.63949819
# China                                                18.95851917
# China                                                 17.6186279
# China                                                15.03704033
# China                                                16.22326642
# ...                                                          ...
# United States                                        12.00739706
# United States                                        12.63791912
# United States                                        12.95382709
# United States                                        13.22859321
# United States                                                 ..
#
#               Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# Country
# China                                                29.73071484
# China                                                28.45581538
# China                                                27.09820152
# China                                                23.94657959
# China                                                20.24947926
# ...                                                          ...
# United States                                        8.481450408
# United States                                        8.713261573
# United States                                        8.754308954
# United States                                        8.716935867
# United States                                                 ..
#
#               Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# Country
# China                                                    1355738
# China                                                    1480949
# China                                                    1654164
# China                                                    1910755
# China                                                    2203502
# ...                                                          ...
# United States                                            4270884
# United States                                            4287114
# United States                                            4319156
# United States                                            4297048
# United States                                                 ..
#
#               Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# Country
# China                                                30187188.73
# China                                                30940867.04
# China                                                32272543.97
# China                                                35505254.39
# China                                                41469975.08
# ...                                                          ...
# United States                                        56628804.85
# United States                                        57984073.56
# United States                                        59116385.16
# United States                                        58483061.91
# United States                                                 ..
#
# [68 rows x 8 columns]

# %% [markdown]
# ### Reform the DF to a suitable form

# %%
# Reset index to return DF to a tidy state
df_p=df_p.reset_index()

# %%
df_p.columns
# Out:
# Index(['Country', 'Country Code', 'Years', 'Time Code',
#        'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]',
#        'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]',
#        'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]',
#        'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]',
#        'Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]'],
#       dtype='object')

# %%
df_p = df_p.drop(['Country Code', 'Time Code', 'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]',
       'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]',
       'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]',
       'Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]'], axis = 1)

# %%
df_p
# Out:
#           Country  Years  \
# 0           China   2000
# 1           China   2001
# 2           China   2002
# 3           China   2003
# 4           China   2004
# ..            ...    ...
# 63  United States   2012
# 64  United States   2013
# 65  United States   2014
# 66  United States   2015
# 67  United States   2016
#
#    Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]
# 0                                         10.23305051
# 1                                         9.833583306
# 2                                         9.621842057
# 3                                         9.994209983
# 4                                         10.35599738
# ..                                                ...
# 63                                        5.692995246
# 64                                        5.676035631
# 65                                        5.621145713
# 66                                         5.40839254
# 67                                                 ..
#
# [68 rows x 3 columns]

# %% [markdown]
# ### 2.4 Do further necessary adjustments

# %%
# Show column types
display(df_p.dtypes)

# %%
df_p.to_csv('result_df/preva_inten.csv')
