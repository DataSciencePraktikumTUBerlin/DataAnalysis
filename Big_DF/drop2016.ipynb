# %%
import pandas as pd

# %%
df = pd.read_csv('result_df/preva_econ.csv', index_col=0)

# %%
df
# Out:
#           Country  Years  \
# 0           China   2000
# 1           China   2001
# 2           China   2002
# 3           China   2003
# 4           China   2004
# ..            ...    ...
# 63  United States   2012
# 64  United States   2013
# 65  United States   2014
# 66  United States   2015
# 67  United States   2016
#
#    Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                         30187188.73
# 1                                         30940867.04
# 2                                         32272543.97
# 3                                         35505254.39
# 4                                         41469975.08
# ..                                                ...
# 63                                        56628804.85
# 64                                        57984073.56
# 65                                        59116385.16
# 66                                        58483061.91
# ...

# %%
# get names of indexes for which 
# column Age has value 21 
index_names = df[ df['Years'] == 2016 ].index 
index_names
# Out:
# Int64Index([16, 33, 50, 67], dtype='int64')

# %%
# drop these row indexes 
# from dataFrame 
df.drop(index_names, inplace = True) 
df
# Out:
#           Country  Years  \
# 0           China   2000
# 1           China   2001
# 2           China   2002
# 3           China   2003
# 4           China   2004
# ..            ...    ...
# 62  United States   2011
# 63  United States   2012
# 64  United States   2013
# 65  United States   2014
# 66  United States   2015
#
#    Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                         30187188.73
# 1                                         30940867.04
# 2                                         32272543.97
# 3                                         35505254.39
# 4                                         41469975.08
# ..                                                ...
# 62                                        57123701.65
# 63                                        56628804.85
# 64                                        57984073.56
# 65                                        59116385.16
# ...

# %%
# save df in csv file
df.to_csv('result_df/preva_econ.csv')
