# %% [markdown]
# # Generate Dataframe for each indicator, with homogene format
# This **pipeline** shows how to generate a a consistent dataframe, and its .csv file, from the *source* folder. It is a generic version, which means that for each file minor changes will be needed.

# %% [markdown]
# ## Preliminars

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Call desired data
df_meta = pd.read_csv('Indicators_metadata.csv')
source_name = 'bp_elec_gen_other'
df = pd.read_csv('source_data/Energy/' + source_name + '.csv', index_col=0)  # index_col=0 reads without 'Unnamed: 0'

# %%
# call metadata of the indicator
df_meta_temp = df_meta.set_index('SOURCE FILE')
Units_ind= df_meta_temp['UNIT'][source_name]
Origin_ind= df_meta_temp['SITE'][source_name]
Name_ind =  df_meta_temp['INDICATOR'][source_name]
Key_ind =  df_meta_temp['KEY'][source_name]
Desc_ind =  df_meta_temp['DESCRIPTION'][source_name]

# %% [markdown]
# ### Preview of the DataFrame

# %%
# Check column names
df.columns
# Out:
# Index(['1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2019.1', '2008-18', '2019.2'],
#       dtype='object')

# %%
df.head()
# Out:
#                          1985      1986      1987      1988      1989  \
# Country
# NaN                       NaN       NaN       NaN       NaN       NaN
# Canada               0.142400  0.137033  0.159700  0.195765  0.102000
# Mexico               0.000000  0.000000  0.000000  0.000000 -0.000770
# US                   0.343859  0.368405  0.373087  0.396913  4.926283
# Total North America  0.486259  0.505438  0.532786  0.592678  5.027513
#
#                           1990       1991       1992       1993       1994  \
# Country
# NaN                        NaN        NaN        NaN        NaN        NaN
# Canada                0.152000   0.152000   0.158000   0.165000   0.165000
# Mexico                0.001901   0.000624   0.001008   0.001050   0.003624
# US                   10.672409  13.009215  13.797283  13.932804  13.696135
# Total North America  10.826310  13.161839  13.956291  14.098854  13.864759
#
#                      ...       2013       2014       2015       2016  \
# Country              ...
# NaN                  ...        NaN        NaN        NaN        NaN
# Canada               ...   3.793996   0.409049   0.457237   0.572290
# Mexico               ...   0.767183   0.655485   0.284077   0.876164
# US                   ...  14.305666  14.071837  14.751862  14.353595
# Total North America  ...  18.866844  15.136371  15.493176  15.802049
#
#                           2017       2018       2019    2019.1   2008-18  \
# Country
# NaN                        NaN        NaN        NaN       NaN       NaN
# Canada                0.520677   0.737882   0.670086 -0.091879 -0.150815
# Mexico                3.506569  20.555161  21.550522  0.048424  0.120144
# US                   13.688822  13.619731  13.960467  0.025018  0.010392
# Total North America  17.716068  34.912774  36.181075  0.036328  0.044100
#
#                        2019.2
# Country
# NaN                       NaN
# Canada               0.002868
# Mexico               0.092240
# US                   0.059753
# Total North America  0.154861
#
# [5 rows x 38 columns]

# %%
# Reset index to return DF to a tidy state IF NEEDED
df=df.reset_index()
# Rename column Country column
# df=df.rename(columns={'Country Name':'Country'})

# %%
df['Country'].unique()
# Out:
# array([nan, 'Canada', 'Mexico', 'US', 'Total North America', 'Argentina',
#        'Brazil', 'Other S. & Cent. America', 'Total S. & Cent. America',
#        'Germany', 'Italy', 'Netherlands', 'Poland', 'Spain', 'Turkey',
#        'Ukraine', 'United Kingdom', 'Other Europe', 'Total Europe',
#        'Kazakhstan', 'Russian Federation', 'Other CIS', 'Total CIS',
#        'Iran', 'Saudi Arabia', 'United Arab Emirates',
#        'Other Middle East', 'Total Middle East', 'Egypt', 'South Africa',
#        'Other Africa', 'Total Africa', 'Australia', 'China', 'India',
#        'Indonesia', 'Japan', 'Malaysia', 'South Korea', 'Taiwan',
#        'Thailand', 'Vietnam', 'Other Asia Pacific', 'Total Asia Pacific',
#        'Total World', 'of which: OECD', '                 Non-OECD',
#        '                 European Union '], dtype=object)

# %%
# selecting rows based on condition 
df = df[df.Country.isin(['China', 'Germany', 'India', 'US'])]

# %%
df
# Out:
#     Country       1985       1986       1987       1988       1989       1990  \
# 3        US   0.343859   0.368405   0.373087   0.396913   4.926283  10.672409
# 11  Germany  14.388321  14.133449  13.680181  15.626727  16.067004  20.158000
# 39    China   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 40    India   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#          1991       1992       1993  ...       2013       2014       2015  \
# 3   13.009215  13.797283  13.932804  ...  14.305666  14.071837  14.751862
# 11  16.200000  16.293700  15.820000  ...  26.180000  26.913000  27.135209
# 39   0.000000   0.000000   0.000242  ...  22.982727  26.146330  26.783590
# 40   0.000000   0.000000   0.000000  ...   0.000000   0.206800   0.137685
#
#          2016       2017       2018       2019    2019.1   2008-18    2019.2
# 3   14.353595  13.688822  13.619731  13.960467  0.025018  0.010392  0.059753
# 11  27.543000  26.743800  26.848000  25.731343 -0.041592  0.008323  0.110134
# 39  42.193500  46.185796  49.791633  56.526133  0.135254  0.000000  0.241941
# 40   0.104105   0.174565   0.206230   0.191505 -0.071401  0.000000  0.000820
#
# [4 rows x 39 columns]

# %%
# Check country name available
# df['Time'].unique()

# %%
# Check column characteristics
df.describe()
# Out:
#             1985       1986       1987       1988       1989       1990  \
# count   4.000000   4.000000   4.000000   4.000000   4.000000   4.000000
# mean    3.683045   3.625464   3.513317   4.005910   5.248322   7.707602
# std     7.138691   7.007476   6.780191   7.749471   7.577101   9.705956
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.171930   0.184203   0.186543   0.198456   2.463142   5.336204
# 75%     3.854975   3.809666   3.699860   4.204367   7.711464  13.043807
# max    14.388321  14.133449  13.680181  15.626727  16.067004  20.158000
#
#             1991       1992       1993       1994  ...       2013       2014  \
# count   4.000000   4.000000   4.000000   4.000000  ...   4.000000   4.000000
# mean    7.302304   7.522746   7.438261   7.771033  ...  15.867098  16.834492
# std     8.532001   8.746101   8.623311   9.095860  ...  11.707419  12.548560
# min     0.000000   0.000000   0.000000   0.000000  ...   0.000000   0.206800
# 25%     0.000000   0.000000   0.000182   0.003597  ...  10.729249  10.605578
# 50%     6.504607   6.898642   6.966523   6.850466  ...  18.644196  20.109084
# 75%    13.806911  14.421387  14.404603  14.617901  ...  23.782045  26.337997
# max    16.200000  16.293700  15.820000  17.383200  ...  26.180000  26.913000
#
#             2015       2016       2017       2018       2019    2019.1  \
# count   4.000000   4.000000   4.000000   4.000000   4.000000  4.000000
# mean   17.202087  21.048550  21.698246  22.616399  24.102362  0.011820
# std    12.749765  18.007211  19.600318  21.130985  24.003761  0.091631
# min     0.137685   0.104105   0.174565   0.206230   0.191505 -0.071401
# 25%    11.098318  10.791222  10.310257  10.266356  10.518226 -0.049044
# 50%    20.767726  20.948297  20.216311  20.233866  19.845905 -0.008287
# 75%    26.871495  31.205625  31.604299  32.583908  33.430041  0.052577
# max    27.135209  42.193500  46.185796  49.791633  56.526133  0.135254
#
#         2008-18    2019.2
# count  4.000000  4.000000
# mean   0.004679  0.103162
# std    0.005468  0.102740
# min    0.000000  0.000820
# 25%    0.000000  0.045020
# 50%    0.004162  0.084944
# 75%    0.008840  0.143086
# max    0.010392  0.241941
#
# [8 rows x 38 columns]

# %%
# Replace country names for consistency with other DataFrames
df['Country']=df['Country'].replace('US', 'United States')
# df['Country']=df['Country'].replace('Deutschland', 'Germany')
# df['Country']=df['Country'].replace('Indien', 'India')

# %%
df
# Out:
#           Country       1985       1986       1987       1988       1989  \
# 3   United States   0.343859   0.368405   0.373087   0.396913   4.926283
# 11        Germany  14.388321  14.133449  13.680181  15.626727  16.067004
# 39          China   0.000000   0.000000   0.000000   0.000000   0.000000
# 40          India   0.000000   0.000000   0.000000   0.000000   0.000000
#
#          1990       1991       1992       1993  ...       2013       2014  \
# 3   10.672409  13.009215  13.797283  13.932804  ...  14.305666  14.071837
# 11  20.158000  16.200000  16.293700  15.820000  ...  26.180000  26.913000
# 39   0.000000   0.000000   0.000000   0.000242  ...  22.982727  26.146330
# 40   0.000000   0.000000   0.000000   0.000000  ...   0.000000   0.206800
#
#          2015       2016       2017       2018       2019    2019.1   2008-18  \
# 3   14.751862  14.353595  13.688822  13.619731  13.960467  0.025018  0.010392
# 11  27.135209  27.543000  26.743800  26.848000  25.731343 -0.041592  0.008323
# 39  26.783590  42.193500  46.185796  49.791633  56.526133  0.135254  0.000000
# 40   0.137685   0.104105   0.174565   0.206230   0.191505 -0.071401  0.000000
#
#       2019.2
# 3   0.059753
# 11  0.110134
# 39  0.241941
# 40  0.000820
#
# [4 rows x 39 columns]

# %%
# drop years before 2000
df.drop(df.iloc[:, 1:16], inplace = True, axis = 1) 
#df = df.iloc[:, 1:3]

# %%
# drop years after 2019
df.drop(df.iloc[:, -3:], inplace = True, axis = 1) 
df
# Out:
#           Country       2000       2001       2002       2003       2004  \
# 3   United States  18.030998  12.227131  13.975489  14.545181  14.750847
# 11        Germany  21.274250  21.279500  18.626250  20.306000  21.226800
# 39          China   0.003687   0.002308   0.006128   0.007895   0.000000
# 40          India   0.000000   0.000000   0.000000   0.000000   0.000000
#
#          2005       2006      2007       2008  ...       2010       2011  \
# 3   13.359156  13.524136  12.70203  12.281998  ...  13.464264  14.801048
# 11  24.146800  25.400600  26.55860  24.712400  ...  26.429300  25.306200
# 39   0.000000   0.000000   0.00000   0.000000  ...  19.851860  21.669000
# 40   0.000000   0.000000   0.00000   0.000000  ...   0.000000   0.000000
#
#          2012       2013       2014       2015       2016       2017  \
# 3   14.502507  14.305666  14.071837  14.751862  14.353595  13.688822
# 11  26.109600  26.180000  26.913000  27.135209  27.543000  26.743800
# 39  20.279890  22.982727  26.146330  26.783590  42.193500  46.185796
# 40   0.000000   0.000000   0.206800   0.137685   0.104105   0.174565
#
#          2018       2019
# 3   13.619731  13.960467
# 11  26.848000  25.731343
# 39  49.791633  56.526133
# 40   0.206230   0.191505
#
# [4 rows x 21 columns]

# %% [markdown]
# ### Set Index temporarily to ease manipulation and guarantee final homogeneity

# %%
index = ['Country']
df=df.set_index(index)

# %%
df
# Out:
#                     2000       2001       2002       2003       2004  \
# Country
# United States  18.030998  12.227131  13.975489  14.545181  14.750847
# Germany        21.274250  21.279500  18.626250  20.306000  21.226800
# China           0.003687   0.002308   0.006128   0.007895   0.000000
# India           0.000000   0.000000   0.000000   0.000000   0.000000
#
#                     2005       2006      2007       2008       2009  \
# Country
# United States  13.359156  13.524136  12.70203  12.281998  12.524095
# Germany        24.146800  25.400600  26.55860  24.712400  21.125200
# China           0.000000   0.000000   0.00000   0.000000   0.000000
# India           0.000000   0.000000   0.00000   0.000000   0.000000
#
#                     2010       2011       2012       2013       2014  \
# Country
# United States  13.464264  14.801048  14.502507  14.305666  14.071837
# Germany        26.429300  25.306200  26.109600  26.180000  26.913000
# China          19.851860  21.669000  20.279890  22.982727  26.146330
# India           0.000000   0.000000   0.000000   0.000000   0.206800
#
#                     2015       2016       2017       2018       2019
# Country
# United States  14.751862  14.353595  13.688822  13.619731  13.960467
# Germany        27.135209  27.543000  26.743800  26.848000  25.731343
# China          26.783590  42.193500  46.185796  49.791633  56.526133
# India           0.137685   0.104105   0.174565   0.206230   0.191505

# %%
# drop all NaNs if any
df.dropna()
# Out:
#                     2000       2001       2002       2003       2004  \
# Country
# United States  18.030998  12.227131  13.975489  14.545181  14.750847
# Germany        21.274250  21.279500  18.626250  20.306000  21.226800
# China           0.003687   0.002308   0.006128   0.007895   0.000000
# India           0.000000   0.000000   0.000000   0.000000   0.000000
#
#                     2005       2006      2007       2008       2009  \
# Country
# United States  13.359156  13.524136  12.70203  12.281998  12.524095
# Germany        24.146800  25.400600  26.55860  24.712400  21.125200
# China           0.000000   0.000000   0.00000   0.000000   0.000000
# India           0.000000   0.000000   0.00000   0.000000   0.000000
#
#                     2010       2011       2012       2013       2014  \
# Country
# United States  13.464264  14.801048  14.502507  14.305666  14.071837
# Germany        26.429300  25.306200  26.109600  26.180000  26.913000
# China          19.851860  21.669000  20.279890  22.982727  26.146330
# India           0.000000   0.000000   0.000000   0.000000   0.206800
#
#                     2015       2016       2017       2018       2019
# Country
# United States  14.751862  14.353595  13.688822  13.619731  13.960467
# Germany        27.135209  27.543000  26.743800  26.848000  25.731343
# China          26.783590  42.193500  46.185796  49.791633  56.526133
# India           0.137685   0.104105   0.174565   0.206230   0.191505

# %% [markdown]
# ### Reform the DF to a suitable form

# %%
# Reset index to return DF to a tidy state
df_p=df.reset_index()

# %%
df_p
# Out:
#          Country       2000       2001       2002       2003       2004  \
# 0  United States  18.030998  12.227131  13.975489  14.545181  14.750847
# 1        Germany  21.274250  21.279500  18.626250  20.306000  21.226800
# 2          China   0.003687   0.002308   0.006128   0.007895   0.000000
# 3          India   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2005       2006      2007       2008  ...       2010       2011  \
# 0  13.359156  13.524136  12.70203  12.281998  ...  13.464264  14.801048
# 1  24.146800  25.400600  26.55860  24.712400  ...  26.429300  25.306200
# 2   0.000000   0.000000   0.00000   0.000000  ...  19.851860  21.669000
# 3   0.000000   0.000000   0.00000   0.000000  ...   0.000000   0.000000
#
#         2012       2013       2014       2015       2016       2017  \
# 0  14.502507  14.305666  14.071837  14.751862  14.353595  13.688822
# 1  26.109600  26.180000  26.913000  27.135209  27.543000  26.743800
# 2  20.279890  22.982727  26.146330  26.783590  42.193500  46.185796
# 3   0.000000   0.000000   0.206800   0.137685   0.104105   0.174565
#
#         2018       2019
# 0  13.619731  13.960467
# 1  26.848000  25.731343
# 2  49.791633  56.526133
# 3   0.206230   0.191505
#
# [4 rows x 21 columns]

# %%
df_p.columns
# Out:
# Index(['Country', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
# Melt to a Long format
df_p=df_p.melt(id_vars='Country')
#df_p2=df_p.melt()

# %%
df_p
# Out:
#           Country variable      value
# 0   United States     2000  18.030998
# 1         Germany     2000  21.274250
# 2           China     2000   0.003687
# 3           India     2000   0.000000
# 4   United States     2001  12.227131
# ..            ...      ...        ...
# 75          India     2018   0.206230
# 76  United States     2019  13.960467
# 77        Germany     2019  25.731343
# 78          China     2019  56.526133
# 79          India     2019   0.191505
#
# [80 rows x 3 columns]

# %%
Name_ind
# Out:
# 'Electricity generation from other'

# %%
# Rename column to Years
df_p=df_p.rename(columns={'variable':'Years'})
df_p=df_p.rename(columns={'value':Name_ind+" "+Units_ind})

# %%
df_p
# Out:
#           Country Years  Electricity generation from other TWh
# 0   United States  2000                              18.030998
# 1         Germany  2000                              21.274250
# 2           China  2000                               0.003687
# 3           India  2000                               0.000000
# 4   United States  2001                              12.227131
# ..            ...   ...                                    ...
# 75          India  2018                               0.206230
# 76  United States  2019                              13.960467
# 77        Germany  2019                              25.731343
# 78          China  2019                              56.526133
# 79          India  2019                               0.191505
#
# [80 rows x 3 columns]

# %% [markdown]
# ### 2.4 Do further necessary adjustments

# %%
# Show column types
display(df_p.dtypes)

# %%
# Coerce column types when needed
df_p.Years=df_p.Years.astype(int, copy=False) #avoiding a warning (careful)

# %%
df_p.head()

# %%
df_p.describe()

# %%
Key_ind
# Out:
# 'c_egen'

# %%
df_p
# Out:
#           Country Years  Electricity generation TWh
# 0   United States  2000                 4052.253106
# 1         Germany  2000                  576.556000
# 2           China  2000                 1355.600000
# 3           India  2000                  571.393936
# 4   United States  2001                 3984.467890
# ..            ...   ...                         ...
# 75          India  2018                 1551.441500
# 76  United States  2019                 4401.299402
# 77        Germany  2019                  612.397325
# 78          China  2019                 7503.428000
# 79          India  2019                 1558.708662
#
# [80 rows x 3 columns]

# %%
df_p.to_csv('result_df/'+'prev'+Key_ind+'.csv')

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/groupwork/DataAnalysis/Big_DF'
