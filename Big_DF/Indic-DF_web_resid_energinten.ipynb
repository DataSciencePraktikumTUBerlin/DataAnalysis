# %% [markdown]
# # Generate Dataframe for each indicator, with homogene format
# This **pipeline** shows how to generate a a consistent dataframe, and its .csv file, from the *source* folder. It is a generic version, which means that for each file minor changes will be needed.

# %% [markdown]
# ## Preliminars

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Call desired data
df_meta = pd.read_csv('Indicators_metadata.csv')
source_name = 'web_resid_energinten'
df = pd.read_csv('source_data/Energy/' + source_name + '.csv', index_col=0)  # index_col=0 reads without 'Unnamed: 0'

# %%
# call metadata of the indicator
df_meta_temp = df_meta.set_index('SOURCE FILE')
Units_ind= df_meta_temp['UNIT'][source_name]
Origin_ind= df_meta_temp['SITE'][source_name]
Name_ind =  df_meta_temp['INDICATOR'][source_name]
Key_ind =  df_meta_temp['KEY'][source_name]
Desc_ind =  df_meta_temp['DESCRIPTION'][source_name]

# %% [markdown]
# ### Preview of the DataFrame

# %%
# Check column names
df.columns
# Out:
# Index(['End use', 'Indicator', '2000', '2005', '2010', '2015', '2016', '2017',
#        '2018'],
#       dtype='object')

# %%
df.head()
# Out:
#                              End use  \
# Country
# Australia          Total Residential
# Australia          Total Residential
# Australia          Total Residential
# Australia  Residential space heating
# Australia  Residential space heating
#
#                                                    Indicator 2000 2005 2010  \
# Country
# Australia  Per capita energy intensity (index 2000)      ...  100   99   98
# Australia  Per dwelling energy intensity (index 2000)    ...  100  102  107
# Australia  Per dwelling TC energy intensity (index 2000) ...  100  103  109
# Australia  Per capita energy intensity (index 2000)      ...  100   91   82
# Australia  Per dwelling energy intensity (index 2000)    ...  100   94   90
#
#           2015 2016 2017 2018
# Country
# Australia   93   92   90   89
# Australia  103  103  101  100
# Australia  105  106  102  102
# Australia   78   77   75   73
# Australia   87   86   84   82

# %%
# Reset index to return DF to a tidy state IF NEEDED
df=df.reset_index()
# Rename column Country column
# df=df.rename(columns={'Country Name':'Country'})

# %%
df['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Poland', 'Portugal',
#        'Slovak Republic', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States', 'Brazil', 'Chile', 'Lithuania',
#        'Morocco', 'Azerbaijan', 'Belarus', 'Kazakhstan', 'Kyrgyzstan'],
#       dtype=object)

# %%
# selecting rows based on condition 
df = df[df.Country.isin(['China', 'Germany', 'India', 'United States'])]

# %%
df
# Out:
#            Country                    End use  \
# 80         Germany          Total Residential
# 81         Germany          Total Residential
# 82         Germany          Total Residential
# 83         Germany  Residential space heating
# 84         Germany  Residential space heating
# 85         Germany  Residential space heating
# 86         Germany       Residential lighting
# 87         Germany       Residential lighting
# 88         Germany     Residential appliances
# 89         Germany     Residential appliances
# 270  United States          Total Residential
# 271  United States          Total Residential
# 272  United States          Total Residential
# 273  United States  Residential space heating
# 274  United States  Residential space heating
# 275  United States  Residential space heating
# 276  United States       Residential lighting
# 277  United States       Residential lighting
# 278  United States     Residential appliances
# 279  United States     Residential appliances
#
#                                              Indicator 2000 2005 2010 2015  \
# 80   Per capita energy intensity (index 2000)      ...  100  101  107   89
# 81   Per dwelling energy intensity (index 2000)    ...  100   98  100   82
# 82   Per dwelling TC energy intensity (index 2000) ...  100   89   82   78
# 83   Per capita energy intensity (index 2000)      ...  100   98  102   79
# 84   Per dwelling energy intensity (index 2000)    ...  100   95   95   73
# 85   Per dwelling TC energy intensity (index 2000) ...  100   84   72   69
# 86   Per capita energy intensity (index 2000)      ...  100  106  105   93
# 87   Per dwelling energy intensity (index 2000)    ...  100  103   98   87
# 88   Per capita energy intensity (index 2000)      ...  100  106  123  115
# 89   Per dwelling energy intensity (index 2000)    ...  100  102  115  106
# 270  Per capita energy intensity (index 2000)      ...  100   97   96   90
# 271  Per dwelling energy intensity (index 2000)    ...  100   96   97   89
# 272  Per dwelling TC energy intensity (index 2000) ...  100   98   97   92
# 273    Per capita energy intensity (index 2000)         100   83   82   75
# 274    Per dwelling energy intensity (index 2000)       100   83   83   75
# 275    Per dwelling TC energy intensity (index 2000)    100   85   84   81
# 276  Per capita energy intensity (index 2000)      ...  100  102   93   63
# 277  Per dwelling energy intensity (index 2000)    ...  100  101   94   63
# 278  Per capita energy intensity (index 2000)      ...  100  117  115  114
# 279  Per dwelling energy intensity (index 2000)    ...  100  116  116  114
#
#     2016 2017 2018
# 80    91   88   86
# 81    84   82   79
# 82    78   77   78
# 83    82   78   74
# 84    76   73   69
# 85    69   67   68
# 86    88   88   90
# 87    82   82   83
# 88   106  106  103
# 89    99   98   96
# 270   85   85   91
# 271   84   84   89
# 272   89   90   90
# 273   66   67   76
# 274   65   66   75
# 275   75   77   79
# 276   64   62   59
# 277   64   62   58
# 278  114  117  116
# 279  113  116  113

# %%
# Check column characteristics
df.describe()
# Out:
#               Country                    End use  \
# count              20                         20
# unique              2                          4
# top     United States  Residential space heating
# freq               10                          6
#
#                                               Indicator 2000 2005 2010 2015  \
# count                                                20   20   20   20   20
# unique                                               20    1   14   17   16
# top     Per dwelling TC energy intensity (index 2000)    100   98  115   63
# freq                                                  1   20    3    2    2
#
#        2016 2017 2018
# count    20   20   20
# unique   17   15   18
# top      64   62   90
# freq      2    2    2

# %%
# Replace country names for consistency with other DataFrames
df['Country']=df['Country'].replace('US', 'United States')
# df['Country']=df['Country'].replace('Deutschland', 'Germany')
# df['Country']=df['Country'].replace('Indien', 'India')

# %%
df
# Out:
#            Country                    End use  \
# 80         Germany          Total Residential
# 81         Germany          Total Residential
# 82         Germany          Total Residential
# 83         Germany  Residential space heating
# 84         Germany  Residential space heating
# 85         Germany  Residential space heating
# 86         Germany       Residential lighting
# 87         Germany       Residential lighting
# 88         Germany     Residential appliances
# 89         Germany     Residential appliances
# 270  United States          Total Residential
# 271  United States          Total Residential
# 272  United States          Total Residential
# 273  United States  Residential space heating
# 274  United States  Residential space heating
# 275  United States  Residential space heating
# 276  United States       Residential lighting
# 277  United States       Residential lighting
# 278  United States     Residential appliances
# 279  United States     Residential appliances
#
#                                              Indicator 2000 2005 2010 2015  \
# 80   Per capita energy intensity (index 2000)      ...  100  101  107   89
# 81   Per dwelling energy intensity (index 2000)    ...  100   98  100   82
# 82   Per dwelling TC energy intensity (index 2000) ...  100   89   82   78
# 83   Per capita energy intensity (index 2000)      ...  100   98  102   79
# 84   Per dwelling energy intensity (index 2000)    ...  100   95   95   73
# 85   Per dwelling TC energy intensity (index 2000) ...  100   84   72   69
# 86   Per capita energy intensity (index 2000)      ...  100  106  105   93
# 87   Per dwelling energy intensity (index 2000)    ...  100  103   98   87
# 88   Per capita energy intensity (index 2000)      ...  100  106  123  115
# 89   Per dwelling energy intensity (index 2000)    ...  100  102  115  106
# 270  Per capita energy intensity (index 2000)      ...  100   97   96   90
# 271  Per dwelling energy intensity (index 2000)    ...  100   96   97   89
# 272  Per dwelling TC energy intensity (index 2000) ...  100   98   97   92
# 273    Per capita energy intensity (index 2000)         100   83   82   75
# 274    Per dwelling energy intensity (index 2000)       100   83   83   75
# 275    Per dwelling TC energy intensity (index 2000)    100   85   84   81
# 276  Per capita energy intensity (index 2000)      ...  100  102   93   63
# 277  Per dwelling energy intensity (index 2000)    ...  100  101   94   63
# 278  Per capita energy intensity (index 2000)      ...  100  117  115  114
# 279  Per dwelling energy intensity (index 2000)    ...  100  116  116  114
#
#     2016 2017 2018
# 80    91   88   86
# 81    84   82   79
# 82    78   77   78
# 83    82   78   74
# 84    76   73   69
# 85    69   67   68
# 86    88   88   90
# 87    82   82   83
# 88   106  106  103
# 89    99   98   96
# 270   85   85   91
# 271   84   84   89
# 272   89   90   90
# 273   66   67   76
# 274   65   66   75
# 275   75   77   79
# 276   64   62   59
# 277   64   62   58
# 278  114  117  116
# 279  113  116  113

# %%
# drop years before 2000
df.drop(df.iloc[:, 1:3], inplace = True, axis = 1) 
#df = df.iloc[:, 1:3]

# %%
# drop years after 2019
#df.drop(df.iloc[:, -3:], inplace = True, axis = 1) 
df
# Out:
#            Country 2000 2005 2010 2015 2016 2017 2018
# 80         Germany  100  101  107   89   91   88   86
# 81         Germany  100   98  100   82   84   82   79
# 82         Germany  100   89   82   78   78   77   78
# 83         Germany  100   98  102   79   82   78   74
# 84         Germany  100   95   95   73   76   73   69
# 85         Germany  100   84   72   69   69   67   68
# 86         Germany  100  106  105   93   88   88   90
# 87         Germany  100  103   98   87   82   82   83
# 88         Germany  100  106  123  115  106  106  103
# 89         Germany  100  102  115  106   99   98   96
# 270  United States  100   97   96   90   85   85   91
# 271  United States  100   96   97   89   84   84   89
# 272  United States  100   98   97   92   89   90   90
# 273  United States  100   83   82   75   66   67   76
# 274  United States  100   83   83   75   65   66   75
# 275  United States  100   85   84   81   75   77   79
# 276  United States  100  102   93   63   64   62   59
# 277  United States  100  101   94   63   64   62   58
# 278  United States  100  117  115  114  114  117  116
# 279  United States  100  116  116  114  113  116  113

# %% [markdown]
# ### Set Index temporarily to ease manipulation and guarantee final homogeneity

# %%
index = ['Country']
df=df.set_index(index)

# %%
df
# Out:
#               2000 2005 2010 2015 2016 2017 2018
# Country
# Germany        100  101  107   89   91   88   86
# Germany        100   98  100   82   84   82   79
# Germany        100   89   82   78   78   77   78
# Germany        100   98  102   79   82   78   74
# Germany        100   95   95   73   76   73   69
# Germany        100   84   72   69   69   67   68
# Germany        100  106  105   93   88   88   90
# Germany        100  103   98   87   82   82   83
# Germany        100  106  123  115  106  106  103
# Germany        100  102  115  106   99   98   96
# United States  100   97   96   90   85   85   91
# United States  100   96   97   89   84   84   89
# United States  100   98   97   92   89   90   90
# United States  100   83   82   75   66   67   76
# United States  100   83   83   75   65   66   75
# United States  100   85   84   81   75   77   79
# United States  100  102   93   63   64   62   59
# United States  100  101   94   63   64   62   58
# United States  100  117  115  114  114  117  116
# United States  100  116  116  114  113  116  113

# %%
# drop all NaNs if any
df.dropna()
# Out:
#               2000 2005 2010 2015 2016 2017 2018
# Country
# Germany        100  101  107   89   91   88   86
# Germany        100   98  100   82   84   82   79
# Germany        100   89   82   78   78   77   78
# Germany        100   98  102   79   82   78   74
# Germany        100   95   95   73   76   73   69
# Germany        100   84   72   69   69   67   68
# Germany        100  106  105   93   88   88   90
# Germany        100  103   98   87   82   82   83
# Germany        100  106  123  115  106  106  103
# Germany        100  102  115  106   99   98   96
# United States  100   97   96   90   85   85   91
# United States  100   96   97   89   84   84   89
# United States  100   98   97   92   89   90   90
# United States  100   83   82   75   66   67   76
# United States  100   83   83   75   65   66   75
# United States  100   85   84   81   75   77   79
# United States  100  102   93   63   64   62   59
# United States  100  101   94   63   64   62   58
# United States  100  117  115  114  114  117  116
# United States  100  116  116  114  113  116  113

# %% [markdown]
# ### Reform the DF to a suitable form

# %%
# Reset index to return DF to a tidy state
df_p=df.reset_index()

# %%
df_p
# Out:
#           Country 2000 2005 2010 2015 2016 2017 2018
# 0         Germany  100  101  107   89   91   88   86
# 1         Germany  100   98  100   82   84   82   79
# 2         Germany  100   89   82   78   78   77   78
# 3         Germany  100   98  102   79   82   78   74
# 4         Germany  100   95   95   73   76   73   69
# 5         Germany  100   84   72   69   69   67   68
# 6         Germany  100  106  105   93   88   88   90
# 7         Germany  100  103   98   87   82   82   83
# 8         Germany  100  106  123  115  106  106  103
# 9         Germany  100  102  115  106   99   98   96
# 10  United States  100   97   96   90   85   85   91
# 11  United States  100   96   97   89   84   84   89
# 12  United States  100   98   97   92   89   90   90
# 13  United States  100   83   82   75   66   67   76
# 14  United States  100   83   83   75   65   66   75
# 15  United States  100   85   84   81   75   77   79
# 16  United States  100  102   93   63   64   62   59
# 17  United States  100  101   94   63   64   62   58
# 18  United States  100  117  115  114  114  117  116
# 19  United States  100  116  116  114  113  116  113

# %%
df_p.columns
# Out:
# Index(['Country', '2000', '2005', '2010', '2015', '2016', '2017', '2018'], dtype='object')

# %%
# Melt to a Long format
df_p=df_p.melt(id_vars='Country')
#df_p2=df_p.melt()

# %%
df_p
# Out:
#            Country variable value
# 0          Germany     2000   100
# 1          Germany     2000   100
# 2          Germany     2000   100
# 3          Germany     2000   100
# 4          Germany     2000   100
# ..             ...      ...   ...
# 135  United States     2018    79
# 136  United States     2018    59
# 137  United States     2018    58
# 138  United States     2018   116
# 139  United States     2018   113
#
# [140 rows x 3 columns]

# %%
Name_ind
# Out:
# 'WEB Residential Energy Indicators'

# %%
# Rename column to Years
df_p=df_p.rename(columns={'variable':'Years'})
df_p=df_p.rename(columns={'value':Name_ind+" "+Units_ind})

# %%
df_p
# Out:
#            Country Years WEB Residential Energy Indicators indexed
# 0          Germany  2000                                       100
# 1          Germany  2000                                       100
# 2          Germany  2000                                       100
# 3          Germany  2000                                       100
# 4          Germany  2000                                       100
# ..             ...   ...                                       ...
# 135  United States  2018                                        79
# 136  United States  2018                                        59
# 137  United States  2018                                        58
# 138  United States  2018                                       116
# 139  United States  2018                                       113
#
# [140 rows x 3 columns]

# %% [markdown]
# ### 2.4 Do further necessary adjustments

# %%
# Show column types
display(df_p.dtypes)

# %%
# Coerce column types when needed
df_p.Years=df_p.Years.astype(int, copy=False) #avoiding a warning (careful)

# %%
df_p.head()

# %%
df_p.describe()

# %%
Key_ind
# Out:
# 'e_resd'

# %%
df_p
# Out:
#            Country Years WEB Residential Energy Indicators indexed
# 0          Germany  2000                                       100
# 1          Germany  2000                                       100
# 2          Germany  2000                                       100
# 3          Germany  2000                                       100
# 4          Germany  2000                                       100
# ..             ...   ...                                       ...
# 135  United States  2018                                        79
# 136  United States  2018                                        59
# 137  United States  2018                                        58
# 138  United States  2018                                       116
# 139  United States  2018                                       113
#
# [140 rows x 3 columns]

# %%
df_p.to_csv('result_df/'+'prev'+Key_ind+'.csv')

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/groupwork/DataAnalysis/Big_DF'
