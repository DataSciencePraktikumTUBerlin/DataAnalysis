# %% [markdown]
# # Plot the general DataFrame

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Here some features of the seaborn package or an eventual coupling 
# with R to use the GGPlot library is to be introduced
# Use Guillermo's preferences for graph aesthetics
sns.set_context('notebook')
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
 df_graph= pd.read_csv('General_Dataframe.csv')

# %%
df_graph.dtypes
# Out:
# Unnamed: 0                                                                                     int64
# Country                                                                                       object
# Years                                                                                          int64
# Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]                    object
# Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]                               object
# Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]     object
# Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]     object
# Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]                               object
# Renewable share electricity production                                                       float64
# Wind and solar share electricity production%                                                 float64
# Electricity generation TWh                                                                   float64
# Electricity generation from other TWh                                                        float64
# Renewable Energy Geothermal (Installed capacity)MW                                           float64
# Renewable Energy Solar (Installed capacity) MW                                               float64
# Renewable Energy Wind  (Installed capacity) MW                                               float64
# Primary Energy: Consumption EJ                                                               float64
# Renewables:Consumption EJ                                                                    float64
# WEB Services Energy Indicators indexed                                                       float64
# Renewable installed PV Power GW                                                              float64
# Renewable installed Wind Power GW                                                            float64
# dtype: object

# %%
df_graph.dtypes.tolist()
# Out:
# [dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64')]

# %%
del df_graph['Unnamed: 0']

# %%
indicators = df_graph.columns.to_list()

# %%
indicators.pop(indicators.index('Country'))+ indicators.pop(indicators.index('Years'))
# Out:
# 'CountryYears'

# %%
indicators
# Out:
# ['Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]',
#  'Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]',
#  'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]',
#  'Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]',
#  'Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]',
#  'Renewable share electricity production',
#  'Wind and solar share electricity production%',
#  'Electricity generation TWh',
#  'Electricity generation from other TWh',
#  'Renewable Energy Geothermal (Installed capacity)MW',
#  'Renewable Energy Solar (Installed capacity) MW',
#  'Renewable Energy Wind  (Installed capacity) MW',
#  'Primary Energy: Consumption EJ',
#  'Renewables:Consumption EJ',
#  'WEB Services Energy Indicators indexed',
#  'Renewable installed PV Power GW',
#  'Renewable installed Wind Power GW']

# %%
for indic in indicators:
    # Set figure size (width, height) in inches 
    fig, ax = plt.subplots(figsize = ( 15 , 6 )) 
    # Plot the scatterplot 
    sns.pointplot(ax = ax , x='Years', y=indic, data=df_graph, hue='Country')
    # Set label for x-axis 
    ax.set_xlabel( 'Years' , size = 12 ) 
    # Set label for y-axis 
    ax.set_ylabel( indic , size = 12 ) 
    # Set title for plot 
    ax.set_title( indic , size = 24 ) 
    # Save the figure
    plt.savefig(indic +'.jpg')
    # Display figure 
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-f35d8e2e1f8e> in <module>
#      11     ax.set_title( indic , size = 24 )
#      12     # Save the figure
# ---> 13     plt.savefig(indic +'.jpg')
#      14     # Display figure
#      15     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_jpg(self, filename_or_obj, dryrun, pil_kwargs, *args, **kwargs)
#     597             pil_kwargs.setdefault("quality", rcParams["savefig.jpeg_quality"])
#     598             pil_kwargs.setdefault("dpi", (self.figure.dpi, self.figure.dpi))
# --> 599             return background.save(
#     600                 filename_or_obj, format='jpeg', **pil_kwargs)
#     601
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2153                 fp = builtins.open(filename, "r+b")
#    2154             else:
# -> 2155                 fp = builtins.open(filename, "w+b")
#    2156
#    2157         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY].jpg'
