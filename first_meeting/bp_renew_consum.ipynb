# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# load data

# %%
source_name = 'bp_renew_consum.csv'
df = pd.read_csv('source_data/Energy/' + source_name, index_col=0)
#df.set_index("Country", inplace = True)

# %%
df
# Out:
#                                        1965      1966      1967      1968  \
# Country
# NaN                                     NaN       NaN       NaN       NaN
# Canada                             0.000000  0.000000  0.000000  0.000000
# Mexico                             0.000000  0.000000  0.000000  0.000000
# US                                 0.133322  0.140620  0.140736  0.155460
# Total North America                0.133322  0.140620  0.140736  0.155460
# ...                                     ...       ...       ...       ...
# NaN                                     NaN       NaN       NaN       NaN
# Total World                        0.214179  0.233071  0.235538  0.257519
# of which: OECD                     0.179852  0.198060  0.199866  0.221200
#                  Non-OECD          0.034327  0.035011  0.035672  0.036319
#                  European Union #  0.029090  0.039790  0.043160  0.048180
#
#                                        1969      1970      1971      1972  \
# Country
# NaN                                     NaN       NaN       NaN       NaN
# Canada                             0.000000  0.000000  0.000000  0.000000
# Mexico                             0.000000  0.000000  0.000000  0.000000
# US                                 0.162271  0.162359  0.165844  0.186730
# Total North America                0.162271  0.162359  0.165844  0.186730
# ...                                     ...       ...       ...       ...
# NaN                                     NaN       NaN       NaN       NaN
# Total World                        0.269545  0.298667  0.322760  0.347499
# of which: OECD                     0.232580  0.251310  0.256369  0.276382
#                  Non-OECD          0.036966  0.047357  0.066391  0.071118
#                  European Union #  0.052430  0.069403  0.070579  0.069259
#
#                                        1973      1974  ...       2013  \
# Country                                                ...
# NaN                                     NaN       NaN  ...        NaN
# Canada                             0.000000  0.000000  ...   0.290927
# Mexico                             0.001610  0.004630  ...   0.111551
# US                                 0.199897  0.204043  ...   3.756286
# Total North America                0.201507  0.208673  ...   4.158765
# ...                                     ...       ...  ...        ...
# NaN                                     NaN       NaN  ...        NaN
# Total World                        0.368311  0.385606  ...  14.360242
# of which: OECD                     0.297001  0.314516  ...  10.116568
#                  Non-OECD          0.071310  0.071090  ...   4.243674
#                  European Union #  0.074422  0.078293  ...   5.023238
#
#                                         2014       2015       2016       2017  \
# Country
# NaN                                      NaN        NaN        NaN        NaN
# Canada                              0.303300   0.437742   0.488314   0.492008
# Mexico                              0.133273   0.157067   0.170452   0.184147
# US                                  4.039290   4.248825   4.807667   5.239283
# Total North America                 4.475862   4.843633   5.466434   5.915439
# ...                                      ...        ...        ...        ...
# NaN                                      NaN        NaN        NaN        NaN
# Total World                        16.027352  18.081068  20.057078  23.036529
# of which: OECD                     10.936214  12.182050  12.960876  14.323605
#                  Non-OECD           5.091138   5.899018   7.096202   8.712925
#                  European Union #   5.383986   6.023025   6.050515   6.692393
#
#                                         2018       2019    2019.1   2008-18  \
# Country
# NaN                                      NaN        NaN       NaN       NaN
# Canada                              0.503491   0.523399  0.039541  0.134528
# Mexico                              0.216463   0.345292  0.595155  0.102784
# US                                  5.503936   5.828555  0.058979  0.100751
# Total North America                 6.223889   6.697246  0.076055  0.103173
# ...                                      ...        ...       ...       ...
# NaN                                      NaN        NaN       NaN       NaN
# Total World                        25.825912  28.976463  0.121992  0.136902
# of which: OECD                     15.272031  16.770755  0.098135  0.108628
#                  Non-OECD          10.553881  12.205708  0.156514  0.199398
#                  European Union #   6.969224   7.541291  0.082085  0.104659
#
#                                      2019.2
# Country
# NaN                                     NaN
# Canada                             0.018063
# Mexico                             0.011916
# US                                 0.201148
# Total North America                0.231127
# ...                                     ...
# NaN                                     NaN
# Total World                        1.000000
# of which: OECD                     0.578772
#                  Non-OECD          0.421228
#                  European Union #  0.260256
#
# [111 rows x 58 columns]

# %%
df  = df.iloc[:, 35:-3]
df
# Out:
#                                        2000      2001      2002      2003  \
# Country
# NaN                                     NaN       NaN       NaN       NaN
# Canada                             0.091975  0.099557  0.103387  0.099353
# Mexico                             0.063846  0.062328  0.063517  0.071684
# US                                 0.868178  0.886655  0.996221  1.058536
# Total North America                1.023999  1.048539  1.163126  1.229573
# ...                                     ...       ...       ...       ...
# NaN                                     NaN       NaN       NaN       NaN
# Total World                        2.639702  2.754379  3.097275  3.370340
# of which: OECD                     1.928829  2.027654  2.318875  2.563465
#                  Non-OECD          0.710872  0.726725  0.778400  0.806875
#                  European Union #  0.650380  0.719425  0.877077  1.034605
#
#                                        2004      2005      2006      2007  \
# Country
# NaN                                     NaN       NaN       NaN       NaN
# Canada                             0.104896  0.103853  0.128107  0.137117
# Mexico                             0.074377  0.082757  0.076331  0.084966
# US                                 1.152707  1.241083  1.468457  1.679495
# Total North America                1.331980  1.427694  1.672895  1.901578
# ...                                     ...       ...       ...       ...
# NaN                                     NaN       NaN       NaN       NaN
# Total World                        3.869028  4.371778  5.026240  5.944938
# of which: OECD                     2.958403  3.380278  3.932512  4.604687
#                  Non-OECD          0.910625  0.991500  1.093728  1.340252
#                  European Union #  1.296742  1.557544  1.835124  2.210652
#
#                                        2008      2009      2010       2011  \
# Country
# NaN                                     NaN       NaN       NaN        NaN
# Canada                             0.142507  0.182543  0.216234   0.250820
# Mexico                             0.081373  0.081211  0.086040   0.088399
# US                                 2.107577  2.394484  2.756646   3.090966
# Total North America                2.331457  2.658238  3.058920   3.430186
# ...                                     ...       ...       ...        ...
# NaN                                     NaN       NaN       NaN        NaN
# Total World                        7.158576  8.240148  9.699337  11.120646
# of which: OECD                     5.445493  6.160191  7.119965   8.157404
#                  Non-OECD          1.713083  2.079958  2.579372   2.963241
#                  European Union #  2.575745  2.917109  3.376245   3.980388
#
#                                         2012       2013       2014       2015  \
# Country
# NaN                                      NaN        NaN        NaN        NaN
# Canada                              0.278884   0.290927   0.303300   0.437742
# Mexico                              0.102050   0.111551   0.133273   0.157067
# US                                  3.325100   3.756286   4.039290   4.248825
# Total North America                 3.706035   4.158765   4.475862   4.843633
# ...                                      ...        ...        ...        ...
# NaN                                      NaN        NaN        NaN        NaN
# Total World                        12.604510  14.360242  16.027352  18.081068
# of which: OECD                      9.131990  10.116568  10.936214  12.182050
#                  Non-OECD           3.472520   4.243674   5.091138   5.899018
#                  European Union #   4.615612   5.023238   5.383986   6.023025
#
#                                         2016       2017       2018       2019
# Country
# NaN                                      NaN        NaN        NaN        NaN
# Canada                              0.488314   0.492008   0.503491   0.523399
# Mexico                              0.170452   0.184147   0.216463   0.345292
# US                                  4.807667   5.239283   5.503936   5.828555
# Total North America                 5.466434   5.915439   6.223889   6.697246
# ...                                      ...        ...        ...        ...
# NaN                                      NaN        NaN        NaN        NaN
# Total World                        20.057078  23.036529  25.825912  28.976463
# of which: OECD                     12.960876  14.323605  15.272031  16.770755
#                  Non-OECD           7.096202   8.712925  10.553881  12.205708
#                  European Union #   6.050515   6.692393   6.969224   7.541291
#
# [111 rows x 20 columns]

# %% [markdown]
# build plots for the countries we research

# %%
years = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
countries = ['Germany', 'US', 'China', 'India']

# Set figsize, grid and loop over our countries
fig, ax = plt.pyplot.subplots(1,1, figsize=(14,6))
ax.grid(color='lightgrey')
for country in countries:
    y = df.loc[country]
    ax.plot(years, y)

# Set labels and legend
ax.set_title('renewable Energy Consumption', size = 20)
ax.legend(countries)
ax.xaxis.set_label_text('Years', size = 16)
ax.yaxis.set_label_text('Exajoules', size = 16)

# Save the figure. must be saved before .show()
plt.pyplot.savefig('bp_renew_consum.png')

# Show figure
plt.pyplot.show()

# %%
pwd
# Out:
# '/Users/paul/Desktop/TU/1datascience/groupwork/DataAnalysis/first_meeting'
