# %%
import pandas as pd

# %%
folder = './Data Formated'
files = ['investment_trends.csv',
        'NEX_returns.csv',
        'policies.csv']

# %%
df1 = pd.read_csv(f'{folder}/{files[0]}', index_col=0)
df2 = pd.read_csv(f'{folder}/{files[1]}', index_col=0)

df1.merge(df2, on=['Country', 'Year'])
# Out:
#           Country  Year  Government R&D  Corporate R&D  Venture capital  \
# 0           China  2000           0.000          0.000            0.000
# 1           China  2001           0.000          0.000            0.000
# 2           China  2002           0.000          0.000            0.000
# 3           China  2003           0.000          0.000            0.000
# 4           China  2004           0.076          0.076            0.016
# ..            ...   ...             ...            ...              ...
# 75  United States  2015           1.056          0.984            0.336
# 76  United States  2016           1.275          1.075            0.200
# 77  United States  2017           1.224          1.656            0.192
# 78  United States  2018           1.320          1.872            0.048
# 79  United States  2019           1.368          1.848            0.048
#
#     Private equity expansion capital  Public markets  Asset finance  \
# ...

# %%
df = pd.DataFrame()

for file in files:
    file = f'{folder}/{file}'
    
    if df.size == 0:
        df = pd.read_csv(file, index_col=0)

        continue

    df2 = pd.read_csv(file, index_col=0)
    df = df.merge(df2, on=['Country', 'Year'])
    
df
# Out:
#           Country  Year  Government R&D  Corporate R&D  Venture capital  \
# 0           China  2000           0.000          0.000            0.000
# 1           China  2001           0.000          0.000            0.000
# 2           China  2002           0.000          0.000            0.000
# 3           China  2003           0.000          0.000            0.000
# 4           China  2004           0.076          0.076            0.016
# ..            ...   ...             ...            ...              ...
# 75  United States  2015           1.056          0.984            0.336
# 76  United States  2016           1.275          1.075            0.200
# 77  United States  2017           1.224          1.656            0.192
# 78  United States  2018           1.320          1.872            0.048
# 79  United States  2019           1.368          1.848            0.048
#
#     Private equity expansion capital  Public markets  Asset finance  \
# ...

# %%
df.to_csv('')
